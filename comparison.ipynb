# %%
# !pip install deepface mtcnn tensorflow kaggle --quiet

# --- IMPORT LIBRARY ---
import itertools
import os
import pandas as pd
import time
from deepface import DeepFace
from collections import defaultdict
import random

# --- KONFIGURASI EKSPERIMEN ---
DATASET_FOLDER = "dataset_foto_tes"
IDENTITY_FILE = "identity_CelebA.txt"
OUTPUT_CSV = "100photo_comparison_results.csv"

MODELS = ["Facenet", "OpenFace", "ArcFace"]
BACKENDS = ["opencv", "ssd", "mtcnn", "retinaface"]
METRICS = ["cosine", "euclidean"]

# --- FUNGSI HELPER ---
def get_result_type(is_same_person, verified):
    if is_same_person and verified: return "TP"
    elif not is_same_person and not verified: return "TN"
    elif not is_same_person and verified: return "FP"
    elif is_same_person and not verified: return "FN"
    return "UNKNOWN"

# --- LANGKAH 1: MEMBACA ULANG IDENTITAS FOTO ---
all_files_in_dataset = os.listdir(DATASET_FOLDER)
filename_to_id = {}
with open(IDENTITY_FILE, 'r') as f:
    for line in f:
        filename, person_id = line.strip().split()
        if filename in all_files_in_dataset:
            filename_to_id[filename] = person_id

# --- LANGKAH 2: MEMBUAT PASANGAN POSITIF & NEGATIF ---
positive_pairs = []
negative_pairs = []
grouped_by_id = defaultdict(list)
for filename, person_id in filename_to_id.items():
    grouped_by_id[person_id].append(filename)

# Pasangan positif: kombinasi dari foto dalam satu ID
for person_id, photos in grouped_by_id.items():
    positive_pairs.extend(list(itertools.combinations(photos, 2)))

# Pasangan negatif: kombinasi satu foto dari tiap ID
representative_photos = [photos[0] for photos in grouped_by_id.values()]
negative_pairs.extend(list(itertools.combinations(representative_photos, 2)))

all_pairs = positive_pairs + negative_pairs
random.shuffle(all_pairs)
print(f"Total pasangan yang akan diuji: {len(all_pairs)} ({len(positive_pairs)} Positif, {len(negative_pairs)} Negatif).")

# --- LANGKAH 3: PROSES VERIFIKASI UTAMA ---
results = []
total_tasks = len(all_pairs) * len(MODELS) * len(BACKENDS) * len(METRICS)
current_task = 0
start_time = time.time()

print(f"\nMemulai proses verifikasi untuk {total_tasks} tugas...")

for img1_name, img2_name in all_pairs:
    img1_path = os.path.join(DATASET_FOLDER, img1_name)
    img2_path = os.path.join(DATASET_FOLDER, img2_name)

    id1 = filename_to_id.get(img1_name)
    id2 = filename_to_id.get(img2_name)
    is_same_person = (id1 == id2)

    for model in MODELS:
        for backend in BACKENDS:
            for metric in METRICS:
                current_task += 1
                elapsed_time = time.time() - start_time
                avg_time_per_task = elapsed_time / current_task
                remaining_tasks = total_tasks - current_task
                eta_seconds = int(avg_time_per_task * remaining_tasks)
                eta_minutes = eta_seconds // 60
                eta_secs = eta_seconds % 60
                progress = (current_task / total_tasks) * 100

                print(f"[{current_task}/{total_tasks} | {progress:.2f}%] {img1_name} vs {img2_name} | {model} | {backend} | Metric: {metric} | ETA: {eta_minutes}m {eta_secs}s")

                try:
                    result = DeepFace.verify(
                        img1_path=img1_path, img2_path=img2_path, model_name=model,
                        detector_backend=backend, distance_metric=metric, enforce_detection=True
                    )

                    distance = result.get("distance", 1.0)
                    similarity = "N/A"
                    if metric == 'cosine':
                        similarity = round((1 - min(1.0, distance)) * 100, 2)

                    verified_status = result.get("verified", False)
                    result_type = get_result_type(is_same_person, verified_status)

                    results.append({
                        "img1": img1_name,
                        "img2": img2_name,
                        "is_same_person": is_same_person,
                        "model": model,
                        "backend": backend,
                        "similarity_metric": metric,
                        "distance": distance,
                        "threshold": result.get("threshold"),
                        "similarity": similarity,
                        "verified": verified_status,
                        "result_type": result_type
                    })
                except Exception as e:
                    print(f"  [x] GAGAL: {e}")
                    # Kalau mau log error detail, bisa ditambahkan log to file

# --- LANGKAH 4: SIMPAN HASIL ---
df = pd.DataFrame(results)
df.to_csv(OUTPUT_CSV, index=False)
print(f"\n✅ Proses Selesai. Hasil disimpan ke: {OUTPUT_CSV}")
# Out:
# WARNING:tensorflow:From c:\Users\rafae\AppData\Local\Programs\Python\Python312\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Total pasangan yang akan diuji: 495 (450 Positif, 45 Negatif).
#
# Memulai proses verifikasi untuk 11880 tugas...
# [1/11880 | 0.01%] 019015.jpg vs 029414.jpg | Facenet | opencv | Metric: cosine | ETA: 0m 0s
#   [x] GAGAL: Exception while processing img1_path
# [2/11880 | 0.02%] 019015.jpg vs 029414.jpg | Facenet | opencv | Metric: euclidean | ETA: 309m 23s
#   [x] GAGAL: Exception while processing img1_path
# [3/11880 | 0.03%] 019015.jpg vs 029414.jpg | Facenet | ssd | Metric: cosine | ETA: 207m 4s
# [4/11880 | 0.03%] 019015.jpg vs 029414.jpg | Facenet | ssd | Metric: euclidean | ETA: 186m 15s
# [5/11880 | 0.04%] 019015.jpg vs 029414.jpg | Facenet | mtcnn | Metric: cosine | ETA: 164m 6s
# [6/11880 | 0.05%] 019015.jpg vs 029414.jpg | Facenet | mtcnn | Metric: euclidean | ETA: 167m 17s
# [7/11880 | 0.06%] 019015.jpg vs 029414.jpg | Facenet | retinaface | Metric: cosine | ETA: 157m 18s
# [8/11880 | 0.07%] 019015.jpg vs 029414.jpg | Facenet | retinaface | Metric: euclidean | ETA: 392m 21s
# [9/11880 | 0.08%] 019015.jpg vs 029414.jpg | OpenFace | opencv | Metric: cosine | ETA: 504m 7s
#   [x] GAGAL: Exception while processing img1_path
# [10/11880 | 0.08%] 019015.jpg vs 029414.jpg | OpenFace | opencv | Metric: euclidean | ETA: 470m 14s
#   [x] GAGAL: Exception while processing img1_path
# [11/11880 | 0.09%] 019015.jpg vs 029414.jpg | OpenFace | ssd | Metric: cosine | ETA: 427m 40s
# [12/11880 | 0.10%] 019015.jpg vs 029414.jpg | OpenFace | ssd | Metric: euclidean | ETA: 395m 39s
# [13/11880 | 0.11%] 019015.jpg vs 029414.jpg | OpenFace | mtcnn | Metric: cosine | ETA: 367m 47s
# [14/11880 | 0.12%] 019015.jpg vs 029414.jpg | OpenFace | mtcnn | Metric: euclidean | ETA: 345m 31s
# [15/11880 | 0.13%] 019015.jpg vs 029414.jpg | OpenFace | retinaface | Metric: cosine | ETA: 326m 13s
# [16/11880 | 0.13%] 019015.jpg vs 029414.jpg | OpenFace | retinaface | Metric: euclidean | ETA: 388m 58s
# [17/11880 | 0.14%] 019015.jpg vs 029414.jpg | ArcFace | opencv | Metric: cosine | ETA: 447m 26s
#   [x] GAGAL: Exception while processing img1_path
# [18/11880 | 0.15%] 019015.jpg vs 029414.jpg | ArcFace | opencv | Metric: euclidean | ETA: 438m 1s
#   [x] GAGAL: Exception while processing img1_path
# [19/11880 | 0.16%] 019015.jpg vs 029414.jpg | ArcFace | ssd | Metric: cosine | ETA: 415m 6s
# [20/11880 | 0.17%] 019015.jpg vs 029414.jpg | ArcFace | ssd | Metric: euclidean | ETA: 397m 39s
# [21/11880 | 0.18%] 019015.jpg vs 029414.jpg | ArcFace | mtcnn | Metric: cosine | ETA: 382m 7s
# [22/11880 | 0.19%] 019015.jpg vs 029414.jpg | ArcFace | mtcnn | Metric: euclidean | ETA: 368m 47s
# [23/11880 | 0.19%] 019015.jpg vs 029414.jpg | ArcFace | retinaface | Metric: cosine | ETA: 356m 10s
# [24/11880 | 0.20%] 019015.jpg vs 029414.jpg | ArcFace | retinaface | Metric: euclidean | ETA: 409m 46s
# [25/11880 | 0.21%] 043155.jpg vs 046906.jpg | Facenet | opencv | Metric: cosine | ETA: 467m 13s
# [26/11880 | 0.22%] 043155.jpg vs 046906.jpg | Facenet | opencv | Metric: euclidean | ETA: 455m 56s
# [27/11880 | 0.23%] 043155.jpg vs 046906.jpg | Facenet | ssd | Metric: cosine | ETA: 447m 0s
# [28/11880 | 0.24%] 043155.jpg vs 046906.jpg | Facenet | ssd | Metric: euclidean | ETA: 438m 34s
# [29/11880 | 0.24%] 043155.jpg vs 046906.jpg | Facenet | mtcnn | Metric: cosine | ETA: 428m 54s
# [30/11880 | 0.25%] 043155.jpg vs 046906.jpg | Facenet | mtcnn | Metric: euclidean | ETA: 422m 26s
# [31/11880 | 0.26%] 043155.jpg vs 046906.jpg | Facenet | retinaface | Metric: cosine | ETA: 417m 9s
# [32/11880 | 0.27%] 043155.jpg vs 046906.jpg | Facenet | retinaface | Metric: euclidean | ETA: 464m 30s
# [33/11880 | 0.28%] 043155.jpg vs 046906.jpg | OpenFace | opencv | Metric: cosine | ETA: 498m 52s
# [34/11880 | 0.29%] 043155.jpg vs 046906.jpg | OpenFace | opencv | Metric: euclidean | ETA: 485m 9s
# [35/11880 | 0.29%] 043155.jpg vs 046906.jpg | OpenFace | ssd | Metric: cosine | ETA: 472m 13s
# [36/11880 | 0.30%] 043155.jpg vs 046906.jpg | OpenFace | ssd | Metric: euclidean | ETA: 460m 3s
# [37/11880 | 0.31%] 043155.jpg vs 046906.jpg | OpenFace | mtcnn | Metric: cosine | ETA: 448m 32s
# [38/11880 | 0.32%] 043155.jpg vs 046906.jpg | OpenFace | mtcnn | Metric: euclidean | ETA: 438m 7s
# [39/11880 | 0.33%] 043155.jpg vs 046906.jpg | OpenFace | retinaface | Metric: cosine | ETA: 428m 14s
# [40/11880 | 0.34%] 043155.jpg vs 046906.jpg | OpenFace | retinaface | Metric: euclidean | ETA: 458m 30s
# [41/11880 | 0.35%] 043155.jpg vs 046906.jpg | ArcFace | opencv | Metric: cosine | ETA: 494m 46s
# [42/11880 | 0.35%] 043155.jpg vs 046906.jpg | ArcFace | opencv | Metric: euclidean | ETA: 485m 21s
# [43/11880 | 0.36%] 043155.jpg vs 046906.jpg | ArcFace | ssd | Metric: cosine | ETA: 476m 58s
# [44/11880 | 0.37%] 043155.jpg vs 046906.jpg | ArcFace | ssd | Metric: euclidean | ETA: 468m 24s
# [45/11880 | 0.38%] 043155.jpg vs 046906.jpg | ArcFace | mtcnn | Metric: cosine | ETA: 459m 58s
# [46/11880 | 0.39%] 043155.jpg vs 046906.jpg | ArcFace | mtcnn | Metric: euclidean | ETA: 452m 26s
# [47/11880 | 0.40%] 043155.jpg vs 046906.jpg | ArcFace | retinaface | Metric: cosine | ETA: 445m 18s
# [48/11880 | 0.40%] 043155.jpg vs 046906.jpg | ArcFace | retinaface | Metric: euclidean | ETA: 480m 11s
# [49/11880 | 0.41%] 049972.jpg vs 061069.jpg | Facenet | opencv | Metric: cosine | ETA: 506m 49s
# [50/11880 | 0.42%] 049972.jpg vs 061069.jpg | Facenet | opencv | Metric: euclidean | ETA: 498m 55s
# [51/11880 | 0.43%] 049972.jpg vs 061069.jpg | Facenet | ssd | Metric: cosine | ETA: 491m 12s
# [52/11880 | 0.44%] 049972.jpg vs 061069.jpg | Facenet | ssd | Metric: euclidean | ETA: 483m 52s
# [53/11880 | 0.45%] 049972.jpg vs 061069.jpg | Facenet | mtcnn | Metric: cosine | ETA: 476m 54s
# [54/11880 | 0.45%] 049972.jpg vs 061069.jpg | Facenet | mtcnn | Metric: euclidean | ETA: 471m 10s
# [55/11880 | 0.46%] 049972.jpg vs 061069.jpg | Facenet | retinaface | Metric: cosine | ETA: 465m 21s
# [56/11880 | 0.47%] 049972.jpg vs 061069.jpg | Facenet | retinaface | Metric: euclidean | ETA: 489m 15s
# [57/11880 | 0.48%] 049972.jpg vs 061069.jpg | OpenFace | opencv | Metric: cosine | ETA: 511m 44s
# [58/11880 | 0.49%] 049972.jpg vs 061069.jpg | OpenFace | opencv | Metric: euclidean | ETA: 503m 45s
# [59/11880 | 0.50%] 049972.jpg vs 061069.jpg | OpenFace | ssd | Metric: cosine | ETA: 495m 57s
# [60/11880 | 0.51%] 049972.jpg vs 061069.jpg | OpenFace | ssd | Metric: euclidean | ETA: 488m 31s
# [61/11880 | 0.51%] 049972.jpg vs 061069.jpg | OpenFace | mtcnn | Metric: cosine | ETA: 481m 17s
# [62/11880 | 0.52%] 049972.jpg vs 061069.jpg | OpenFace | mtcnn | Metric: euclidean | ETA: 474m 59s
# [63/11880 | 0.53%] 049972.jpg vs 061069.jpg | OpenFace | retinaface | Metric: cosine | ETA: 468m 51s
# [64/11880 | 0.54%] 049972.jpg vs 061069.jpg | OpenFace | retinaface | Metric: euclidean | ETA: 488m 22s
# [65/11880 | 0.55%] 049972.jpg vs 061069.jpg | ArcFace | opencv | Metric: cosine | ETA: 506m 58s
# [66/11880 | 0.56%] 049972.jpg vs 061069.jpg | ArcFace | opencv | Metric: euclidean | ETA: 500m 26s
# [67/11880 | 0.56%] 049972.jpg vs 061069.jpg | ArcFace | ssd | Metric: cosine | ETA: 494m 10s
# [68/11880 | 0.57%] 049972.jpg vs 061069.jpg | ArcFace | ssd | Metric: euclidean | ETA: 488m 5s
# [69/11880 | 0.58%] 049972.jpg vs 061069.jpg | ArcFace | mtcnn | Metric: cosine | ETA: 482m 13s
# [70/11880 | 0.59%] 049972.jpg vs 061069.jpg | ArcFace | mtcnn | Metric: euclidean | ETA: 477m 6s
# [71/11880 | 0.60%] 049972.jpg vs 061069.jpg | ArcFace | retinaface | Metric: cosine | ETA: 472m 9s
# [72/11880 | 0.61%] 049972.jpg vs 061069.jpg | ArcFace | retinaface | Metric: euclidean | ETA: 490m 19s
# [73/11880 | 0.61%] 034914.jpg vs 044956.jpg | Facenet | opencv | Metric: cosine | ETA: 508m 13s
# [74/11880 | 0.62%] 034914.jpg vs 044956.jpg | Facenet | opencv | Metric: euclidean | ETA: 502m 56s
# [75/11880 | 0.63%] 034914.jpg vs 044956.jpg | Facenet | ssd | Metric: cosine | ETA: 497m 43s
# [76/11880 | 0.64%] 034914.jpg vs 044956.jpg | Facenet | ssd | Metric: euclidean | ETA: 492m 42s
# [77/11880 | 0.65%] 034914.jpg vs 044956.jpg | Facenet | mtcnn | Metric: cosine | ETA: 487m 47s
# [78/11880 | 0.66%] 034914.jpg vs 044956.jpg | Facenet | mtcnn | Metric: euclidean | ETA: 483m 35s
# [79/11880 | 0.66%] 034914.jpg vs 044956.jpg | Facenet | retinaface | Metric: cosine | ETA: 479m 29s
# [80/11880 | 0.67%] 034914.jpg vs 044956.jpg | Facenet | retinaface | Metric: euclidean | ETA: 496m 17s
# [81/11880 | 0.68%] 034914.jpg vs 044956.jpg | OpenFace | opencv | Metric: cosine | ETA: 512m 34s
# [82/11880 | 0.69%] 034914.jpg vs 044956.jpg | OpenFace | opencv | Metric: euclidean | ETA: 506m 59s
# [83/11880 | 0.70%] 034914.jpg vs 044956.jpg | OpenFace | ssd | Metric: cosine | ETA: 501m 29s
# [84/11880 | 0.71%] 034914.jpg vs 044956.jpg | OpenFace | ssd | Metric: euclidean | ETA: 496m 8s
# [85/11880 | 0.72%] 034914.jpg vs 044956.jpg | OpenFace | mtcnn | Metric: cosine | ETA: 490m 56s
# [86/11880 | 0.72%] 034914.jpg vs 044956.jpg | OpenFace | mtcnn | Metric: euclidean | ETA: 486m 16s
# [87/11880 | 0.73%] 034914.jpg vs 044956.jpg | OpenFace | retinaface | Metric: cosine | ETA: 481m 45s
# [88/11880 | 0.74%] 034914.jpg vs 044956.jpg | OpenFace | retinaface | Metric: euclidean | ETA: 495m 50s
# [89/11880 | 0.75%] 034914.jpg vs 044956.jpg | ArcFace | opencv | Metric: cosine | ETA: 509m 33s
# [90/11880 | 0.76%] 034914.jpg vs 044956.jpg | ArcFace | opencv | Metric: euclidean | ETA: 504m 51s
# [91/11880 | 0.77%] 034914.jpg vs 044956.jpg | ArcFace | ssd | Metric: cosine | ETA: 500m 15s
# [92/11880 | 0.77%] 034914.jpg vs 044956.jpg | ArcFace | ssd | Metric: euclidean | ETA: 495m 45s
# [93/11880 | 0.78%] 034914.jpg vs 044956.jpg | ArcFace | mtcnn | Metric: cosine | ETA: 491m 21s
# [94/11880 | 0.79%] 034914.jpg vs 044956.jpg | ArcFace | mtcnn | Metric: euclidean | ETA: 487m 30s
# [95/11880 | 0.80%] 034914.jpg vs 044956.jpg | ArcFace | retinaface | Metric: cosine | ETA: 483m 40s
# [96/11880 | 0.81%] 034914.jpg vs 044956.jpg | ArcFace | retinaface | Metric: euclidean | ETA: 496m 54s
# [97/11880 | 0.82%] 027559.jpg vs 029583.jpg | Facenet | opencv | Metric: cosine | ETA: 510m 5s
# [98/11880 | 0.82%] 027559.jpg vs 029583.jpg | Facenet | opencv | Metric: euclidean | ETA: 506m 3s
# [99/11880 | 0.83%] 027559.jpg vs 029583.jpg | Facenet | ssd | Metric: cosine | ETA: 502m 3s
# [100/11880 | 0.84%] 027559.jpg vs 029583.jpg | Facenet | ssd | Metric: euclidean | ETA: 498m 7s
# [101/11880 | 0.85%] 027559.jpg vs 029583.jpg | Facenet | mtcnn | Metric: cosine | ETA: 494m 18s
# [102/11880 | 0.86%] 027559.jpg vs 029583.jpg | Facenet | mtcnn | Metric: euclidean | ETA: 490m 56s
# [103/11880 | 0.87%] 027559.jpg vs 029583.jpg | Facenet | retinaface | Metric: cosine | ETA: 487m 37s
# [104/11880 | 0.88%] 027559.jpg vs 029583.jpg | Facenet | retinaface | Metric: euclidean | ETA: 499m 36s
# [105/11880 | 0.88%] 027559.jpg vs 029583.jpg | OpenFace | opencv | Metric: cosine | ETA: 511m 36s
# [106/11880 | 0.89%] 027559.jpg vs 029583.jpg | OpenFace | opencv | Metric: euclidean | ETA: 507m 12s
# [107/11880 | 0.90%] 027559.jpg vs 029583.jpg | OpenFace | ssd | Metric: cosine | ETA: 502m 53s
# [108/11880 | 0.91%] 027559.jpg vs 029583.jpg | OpenFace | ssd | Metric: euclidean | ETA: 498m 42s
# [109/11880 | 0.92%] 027559.jpg vs 029583.jpg | OpenFace | mtcnn | Metric: cosine | ETA: 494m 35s
# [110/11880 | 0.93%] 027559.jpg vs 029583.jpg | OpenFace | mtcnn | Metric: euclidean | ETA: 490m 52s
# [111/11880 | 0.93%] 027559.jpg vs 029583.jpg | OpenFace | retinaface | Metric: cosine | ETA: 487m 12s
# [112/11880 | 0.94%] 027559.jpg vs 029583.jpg | OpenFace | retinaface | Metric: euclidean | ETA: 498m 1s
# [113/11880 | 0.95%] 027559.jpg vs 029583.jpg | ArcFace | opencv | Metric: cosine | ETA: 508m 50s
# [114/11880 | 0.96%] 027559.jpg vs 029583.jpg | ArcFace | opencv | Metric: euclidean | ETA: 505m 4s
# [115/11880 | 0.97%] 027559.jpg vs 029583.jpg | ArcFace | ssd | Metric: cosine | ETA: 501m 22s
# [116/11880 | 0.98%] 027559.jpg vs 029583.jpg | ArcFace | ssd | Metric: euclidean | ETA: 497m 46s
# [117/11880 | 0.98%] 027559.jpg vs 029583.jpg | ArcFace | mtcnn | Metric: cosine | ETA: 494m 13s
# [118/11880 | 0.99%] 027559.jpg vs 029583.jpg | ArcFace | mtcnn | Metric: euclidean | ETA: 491m 7s
# [119/11880 | 1.00%] 027559.jpg vs 029583.jpg | ArcFace | retinaface | Metric: cosine | ETA: 488m 1s
# [120/11880 | 1.01%] 027559.jpg vs 029583.jpg | ArcFace | retinaface | Metric: euclidean | ETA: 498m 4s
# [121/11880 | 1.02%] 043521.jpg vs 045445.jpg | Facenet | opencv | Metric: cosine | ETA: 508m 34s
# [122/11880 | 1.03%] 043521.jpg vs 045445.jpg | Facenet | opencv | Metric: euclidean | ETA: 505m 27s
# [123/11880 | 1.04%] 043521.jpg vs 045445.jpg | Facenet | ssd | Metric: cosine | ETA: 502m 15s
# [124/11880 | 1.04%] 043521.jpg vs 045445.jpg | Facenet | ssd | Metric: euclidean | ETA: 499m 10s
# [125/11880 | 1.05%] 043521.jpg vs 045445.jpg | Facenet | mtcnn | Metric: cosine | ETA: 496m 9s
# [126/11880 | 1.06%] 043521.jpg vs 045445.jpg | Facenet | mtcnn | Metric: euclidean | ETA: 493m 33s
# [127/11880 | 1.07%] 043521.jpg vs 045445.jpg | Facenet | retinaface | Metric: cosine | ETA: 490m 56s
# [128/11880 | 1.08%] 043521.jpg vs 045445.jpg | Facenet | retinaface | Metric: euclidean | ETA: 500m 14s
# [129/11880 | 1.09%] 043521.jpg vs 045445.jpg | OpenFace | opencv | Metric: cosine | ETA: 509m 21s
# [130/11880 | 1.09%] 043521.jpg vs 045445.jpg | OpenFace | opencv | Metric: euclidean | ETA: 505m 48s
# [131/11880 | 1.10%] 043521.jpg vs 045445.jpg | OpenFace | ssd | Metric: cosine | ETA: 502m 19s
# [132/11880 | 1.11%] 043521.jpg vs 045445.jpg | OpenFace | ssd | Metric: euclidean | ETA: 498m 52s
# [133/11880 | 1.12%] 043521.jpg vs 045445.jpg | OpenFace | mtcnn | Metric: cosine | ETA: 495m 30s
# [134/11880 | 1.13%] 043521.jpg vs 045445.jpg | OpenFace | mtcnn | Metric: euclidean | ETA: 492m 28s
# [135/11880 | 1.14%] 043521.jpg vs 045445.jpg | OpenFace | retinaface | Metric: cosine | ETA: 489m 30s
# [136/11880 | 1.14%] 043521.jpg vs 045445.jpg | OpenFace | retinaface | Metric: euclidean | ETA: 498m 2s
# [137/11880 | 1.15%] 043521.jpg vs 045445.jpg | ArcFace | opencv | Metric: cosine | ETA: 506m 41s
# [138/11880 | 1.16%] 043521.jpg vs 045445.jpg | ArcFace | opencv | Metric: euclidean | ETA: 503m 33s
# [139/11880 | 1.17%] 043521.jpg vs 045445.jpg | ArcFace | ssd | Metric: cosine | ETA: 500m 28s
# [140/11880 | 1.18%] 043521.jpg vs 045445.jpg | ArcFace | ssd | Metric: euclidean | ETA: 497m 28s
# [141/11880 | 1.19%] 043521.jpg vs 045445.jpg | ArcFace | mtcnn | Metric: cosine | ETA: 494m 31s
# [142/11880 | 1.20%] 043521.jpg vs 045445.jpg | ArcFace | mtcnn | Metric: euclidean | ETA: 491m 56s
# [143/11880 | 1.20%] 043521.jpg vs 045445.jpg | ArcFace | retinaface | Metric: cosine | ETA: 489m 18s
# [144/11880 | 1.21%] 043521.jpg vs 045445.jpg | ArcFace | retinaface | Metric: euclidean | ETA: 497m 20s
# [145/11880 | 1.22%] 015336.jpg vs 033472.jpg | Facenet | opencv | Metric: cosine | ETA: 505m 7s
# [146/11880 | 1.23%] 015336.jpg vs 033472.jpg | Facenet | opencv | Metric: euclidean | ETA: 502m 30s
# [147/11880 | 1.24%] 015336.jpg vs 033472.jpg | Facenet | ssd | Metric: cosine | ETA: 499m 53s
# [148/11880 | 1.25%] 015336.jpg vs 033472.jpg | Facenet | ssd | Metric: euclidean | ETA: 497m 17s
# [149/11880 | 1.25%] 015336.jpg vs 033472.jpg | Facenet | mtcnn | Metric: cosine | ETA: 494m 43s
# [150/11880 | 1.26%] 015336.jpg vs 033472.jpg | Facenet | mtcnn | Metric: euclidean | ETA: 492m 29s
# [151/11880 | 1.27%] 015336.jpg vs 033472.jpg | Facenet | retinaface | Metric: cosine | ETA: 490m 17s
# [152/11880 | 1.28%] 015336.jpg vs 033472.jpg | Facenet | retinaface | Metric: euclidean | ETA: 498m 22s
# [153/11880 | 1.29%] 015336.jpg vs 033472.jpg | OpenFace | opencv | Metric: cosine | ETA: 506m 34s
# [154/11880 | 1.30%] 015336.jpg vs 033472.jpg | OpenFace | opencv | Metric: euclidean | ETA: 503m 36s
# [155/11880 | 1.30%] 015336.jpg vs 033472.jpg | OpenFace | ssd | Metric: cosine | ETA: 500m 39s
# [156/11880 | 1.31%] 015336.jpg vs 033472.jpg | OpenFace | ssd | Metric: euclidean | ETA: 497m 45s
# [157/11880 | 1.32%] 015336.jpg vs 033472.jpg | OpenFace | mtcnn | Metric: cosine | ETA: 494m 53s
# [158/11880 | 1.33%] 015336.jpg vs 033472.jpg | OpenFace | mtcnn | Metric: euclidean | ETA: 492m 20s
# [159/11880 | 1.34%] 015336.jpg vs 033472.jpg | OpenFace | retinaface | Metric: cosine | ETA: 489m 48s
# [160/11880 | 1.35%] 015336.jpg vs 033472.jpg | OpenFace | retinaface | Metric: euclidean | ETA: 496m 43s
# [161/11880 | 1.36%] 015336.jpg vs 033472.jpg | ArcFace | opencv | Metric: cosine | ETA: 503m 50s
# [162/11880 | 1.36%] 015336.jpg vs 033472.jpg | ArcFace | opencv | Metric: euclidean | ETA: 501m 16s
# [163/11880 | 1.37%] 015336.jpg vs 033472.jpg | ArcFace | ssd | Metric: cosine | ETA: 498m 47s
# [164/11880 | 1.38%] 015336.jpg vs 033472.jpg | ArcFace | ssd | Metric: euclidean | ETA: 496m 16s
# [165/11880 | 1.39%] 015336.jpg vs 033472.jpg | ArcFace | mtcnn | Metric: cosine | ETA: 493m 43s
# [166/11880 | 1.40%] 015336.jpg vs 033472.jpg | ArcFace | mtcnn | Metric: euclidean | ETA: 491m 28s
# [167/11880 | 1.41%] 015336.jpg vs 033472.jpg | ArcFace | retinaface | Metric: cosine | ETA: 489m 13s
# [168/11880 | 1.41%] 015336.jpg vs 033472.jpg | ArcFace | retinaface | Metric: euclidean | ETA: 496m 7s
# [169/11880 | 1.42%] 037082.jpg vs 055891.jpg | Facenet | opencv | Metric: cosine | ETA: 502m 58s
# [170/11880 | 1.43%] 037082.jpg vs 055891.jpg | Facenet | opencv | Metric: euclidean | ETA: 500m 43s
# [171/11880 | 1.44%] 037082.jpg vs 055891.jpg | Facenet | ssd | Metric: cosine | ETA: 498m 27s
# [172/11880 | 1.45%] 037082.jpg vs 055891.jpg | Facenet | ssd | Metric: euclidean | ETA: 496m 12s
# [173/11880 | 1.46%] 037082.jpg vs 055891.jpg | Facenet | mtcnn | Metric: cosine | ETA: 494m 1s
# [174/11880 | 1.46%] 037082.jpg vs 055891.jpg | Facenet | mtcnn | Metric: euclidean | ETA: 492m 6s
# [175/11880 | 1.47%] 037082.jpg vs 055891.jpg | Facenet | retinaface | Metric: cosine | ETA: 490m 12s
# [176/11880 | 1.48%] 037082.jpg vs 055891.jpg | Facenet | retinaface | Metric: euclidean | ETA: 496m 44s
# [177/11880 | 1.49%] 037082.jpg vs 055891.jpg | OpenFace | opencv | Metric: cosine | ETA: 503m 15s
# [178/11880 | 1.50%] 037082.jpg vs 055891.jpg | OpenFace | opencv | Metric: euclidean | ETA: 500m 41s
# [179/11880 | 1.51%] 037082.jpg vs 055891.jpg | OpenFace | ssd | Metric: cosine | ETA: 498m 9s
# [180/11880 | 1.52%] 037082.jpg vs 055891.jpg | OpenFace | ssd | Metric: euclidean | ETA: 495m 39s
# [181/11880 | 1.52%] 037082.jpg vs 055891.jpg | OpenFace | mtcnn | Metric: cosine | ETA: 493m 11s
# [182/11880 | 1.53%] 037082.jpg vs 055891.jpg | OpenFace | mtcnn | Metric: euclidean | ETA: 490m 58s
# [183/11880 | 1.54%] 037082.jpg vs 055891.jpg | OpenFace | retinaface | Metric: cosine | ETA: 488m 46s
# [184/11880 | 1.55%] 037082.jpg vs 055891.jpg | OpenFace | retinaface | Metric: euclidean | ETA: 494m 45s
# [185/11880 | 1.56%] 037082.jpg vs 055891.jpg | ArcFace | opencv | Metric: cosine | ETA: 500m 41s
# [186/11880 | 1.57%] 037082.jpg vs 055891.jpg | ArcFace | opencv | Metric: euclidean | ETA: 498m 27s
# [187/11880 | 1.57%] 037082.jpg vs 055891.jpg | ArcFace | ssd | Metric: cosine | ETA: 496m 14s
# [188/11880 | 1.58%] 037082.jpg vs 055891.jpg | ArcFace | ssd | Metric: euclidean | ETA: 494m 4s
# [189/11880 | 1.59%] 037082.jpg vs 055891.jpg | ArcFace | mtcnn | Metric: cosine | ETA: 491m 56s
# [190/11880 | 1.60%] 037082.jpg vs 055891.jpg | ArcFace | mtcnn | Metric: euclidean | ETA: 490m 0s
# [191/11880 | 1.61%] 037082.jpg vs 055891.jpg | ArcFace | retinaface | Metric: cosine | ETA: 488m 7s
# [192/11880 | 1.62%] 037082.jpg vs 055891.jpg | ArcFace | retinaface | Metric: euclidean | ETA: 493m 55s
# [193/11880 | 1.62%] 045318.jpg vs 046844.jpg | Facenet | opencv | Metric: cosine | ETA: 499m 44s
# [194/11880 | 1.63%] 045318.jpg vs 046844.jpg | Facenet | opencv | Metric: euclidean | ETA: 497m 44s
# [195/11880 | 1.64%] 045318.jpg vs 046844.jpg | Facenet | ssd | Metric: cosine | ETA: 495m 44s
# [196/11880 | 1.65%] 045318.jpg vs 046844.jpg | Facenet | ssd | Metric: euclidean | ETA: 493m 48s
# [197/11880 | 1.66%] 045318.jpg vs 046844.jpg | Facenet | mtcnn | Metric: cosine | ETA: 491m 52s
# [198/11880 | 1.67%] 045318.jpg vs 046844.jpg | Facenet | mtcnn | Metric: euclidean | ETA: 490m 14s
# [199/11880 | 1.68%] 045318.jpg vs 046844.jpg | Facenet | retinaface | Metric: cosine | ETA: 488m 33s
# [200/11880 | 1.68%] 045318.jpg vs 046844.jpg | Facenet | retinaface | Metric: euclidean | ETA: 494m 24s
# [201/11880 | 1.69%] 045318.jpg vs 046844.jpg | OpenFace | opencv | Metric: cosine | ETA: 500m 13s
# [202/11880 | 1.70%] 045318.jpg vs 046844.jpg | OpenFace | opencv | Metric: euclidean | ETA: 497m 56s
# [203/11880 | 1.71%] 045318.jpg vs 046844.jpg | OpenFace | ssd | Metric: cosine | ETA: 495m 41s
# [204/11880 | 1.72%] 045318.jpg vs 046844.jpg | OpenFace | ssd | Metric: euclidean | ETA: 493m 29s
# [205/11880 | 1.73%] 045318.jpg vs 046844.jpg | OpenFace | mtcnn | Metric: cosine | ETA: 491m 17s
# [206/11880 | 1.73%] 045318.jpg vs 046844.jpg | OpenFace | mtcnn | Metric: euclidean | ETA: 489m 19s
# [207/11880 | 1.74%] 045318.jpg vs 046844.jpg | OpenFace | retinaface | Metric: cosine | ETA: 487m 21s
# [208/11880 | 1.75%] 045318.jpg vs 046844.jpg | OpenFace | retinaface | Metric: euclidean | ETA: 492m 34s
# [209/11880 | 1.76%] 045318.jpg vs 046844.jpg | ArcFace | opencv | Metric: cosine | ETA: 497m 48s
# [210/11880 | 1.77%] 045318.jpg vs 046844.jpg | ArcFace | opencv | Metric: euclidean | ETA: 495m 49s
# [211/11880 | 1.78%] 045318.jpg vs 046844.jpg | ArcFace | ssd | Metric: cosine | ETA: 493m 50s
# [212/11880 | 1.78%] 045318.jpg vs 046844.jpg | ArcFace | ssd | Metric: euclidean | ETA: 491m 56s
# [213/11880 | 1.79%] 045318.jpg vs 046844.jpg | ArcFace | mtcnn | Metric: cosine | ETA: 490m 1s
# [214/11880 | 1.80%] 045318.jpg vs 046844.jpg | ArcFace | mtcnn | Metric: euclidean | ETA: 488m 19s
# [215/11880 | 1.81%] 045318.jpg vs 046844.jpg | ArcFace | retinaface | Metric: cosine | ETA: 486m 36s
# [216/11880 | 1.82%] 045318.jpg vs 046844.jpg | ArcFace | retinaface | Metric: euclidean | ETA: 491m 41s
# [217/11880 | 1.83%] 021177.jpg vs 070510.jpg | Facenet | opencv | Metric: cosine | ETA: 496m 49s
# [218/11880 | 1.84%] 021177.jpg vs 070510.jpg | Facenet | opencv | Metric: euclidean | ETA: 495m 4s
# [219/11880 | 1.84%] 021177.jpg vs 070510.jpg | Facenet | ssd | Metric: cosine | ETA: 493m 18s
# [220/11880 | 1.85%] 021177.jpg vs 070510.jpg | Facenet | ssd | Metric: euclidean | ETA: 491m 31s
# [221/11880 | 1.86%] 021177.jpg vs 070510.jpg | Facenet | mtcnn | Metric: cosine | ETA: 489m 45s
# [222/11880 | 1.87%] 021177.jpg vs 070510.jpg | Facenet | mtcnn | Metric: euclidean | ETA: 488m 12s
# [223/11880 | 1.88%] 021177.jpg vs 070510.jpg | Facenet | retinaface | Metric: cosine | ETA: 486m 41s
# [224/11880 | 1.89%] 021177.jpg vs 070510.jpg | Facenet | retinaface | Metric: euclidean | ETA: 491m 35s
# [225/11880 | 1.89%] 021177.jpg vs 070510.jpg | OpenFace | opencv | Metric: cosine | ETA: 496m 42s
# [226/11880 | 1.90%] 021177.jpg vs 070510.jpg | OpenFace | opencv | Metric: euclidean | ETA: 494m 42s
# [227/11880 | 1.91%] 021177.jpg vs 070510.jpg | OpenFace | ssd | Metric: cosine | ETA: 492m 42s
# [228/11880 | 1.92%] 021177.jpg vs 070510.jpg | OpenFace | ssd | Metric: euclidean | ETA: 490m 42s
# [229/11880 | 1.93%] 021177.jpg vs 070510.jpg | OpenFace | mtcnn | Metric: cosine | ETA: 488m 45s
# [230/11880 | 1.94%] 021177.jpg vs 070510.jpg | OpenFace | mtcnn | Metric: euclidean | ETA: 486m 58s
# [231/11880 | 1.94%] 021177.jpg vs 070510.jpg | OpenFace | retinaface | Metric: cosine | ETA: 485m 11s
# [232/11880 | 1.95%] 021177.jpg vs 070510.jpg | OpenFace | retinaface | Metric: euclidean | ETA: 490m 2s
# [233/11880 | 1.96%] 021177.jpg vs 070510.jpg | ArcFace | opencv | Metric: cosine | ETA: 494m 47s
# [234/11880 | 1.97%] 021177.jpg vs 070510.jpg | ArcFace | opencv | Metric: euclidean | ETA: 493m 0s
# [235/11880 | 1.98%] 021177.jpg vs 070510.jpg | ArcFace | ssd | Metric: cosine | ETA: 491m 13s
# [236/11880 | 1.99%] 021177.jpg vs 070510.jpg | ArcFace | ssd | Metric: euclidean | ETA: 489m 27s
# [237/11880 | 1.99%] 021177.jpg vs 070510.jpg | ArcFace | mtcnn | Metric: cosine | ETA: 487m 43s
# [238/11880 | 2.00%] 021177.jpg vs 070510.jpg | ArcFace | mtcnn | Metric: euclidean | ETA: 486m 8s
# [239/11880 | 2.01%] 021177.jpg vs 070510.jpg | ArcFace | retinaface | Metric: cosine | ETA: 484m 35s
# [240/11880 | 2.02%] 021177.jpg vs 070510.jpg | ArcFace | retinaface | Metric: euclidean | ETA: 489m 9s
# [241/11880 | 2.03%] 019015.jpg vs 028776.jpg | Facenet | opencv | Metric: cosine | ETA: 493m 28s
#   [x] GAGAL: Exception while processing img1_path
# [242/11880 | 2.04%] 019015.jpg vs 028776.jpg | Facenet | opencv | Metric: euclidean | ETA: 491m 24s
#   [x] GAGAL: Exception while processing img1_path
# [243/11880 | 2.05%] 019015.jpg vs 028776.jpg | Facenet | ssd | Metric: cosine | ETA: 489m 21s
# [244/11880 | 2.05%] 019015.jpg vs 028776.jpg | Facenet | ssd | Metric: euclidean | ETA: 487m 43s
# [245/11880 | 2.06%] 019015.jpg vs 028776.jpg | Facenet | mtcnn | Metric: cosine | ETA: 486m 5s
# [246/11880 | 2.07%] 019015.jpg vs 028776.jpg | Facenet | mtcnn | Metric: euclidean | ETA: 484m 37s
# [247/11880 | 2.08%] 019015.jpg vs 028776.jpg | Facenet | retinaface | Metric: cosine | ETA: 483m 8s
# [248/11880 | 2.09%] 019015.jpg vs 028776.jpg | Facenet | retinaface | Metric: euclidean | ETA: 487m 25s
# [249/11880 | 2.10%] 019015.jpg vs 028776.jpg | OpenFace | opencv | Metric: cosine | ETA: 492m 13s
#   [x] GAGAL: Exception while processing img1_path
# [250/11880 | 2.10%] 019015.jpg vs 028776.jpg | OpenFace | opencv | Metric: euclidean | ETA: 490m 13s
#   [x] GAGAL: Exception while processing img1_path
# [251/11880 | 2.11%] 019015.jpg vs 028776.jpg | OpenFace | ssd | Metric: cosine | ETA: 488m 14s
# [252/11880 | 2.12%] 019015.jpg vs 028776.jpg | OpenFace | ssd | Metric: euclidean | ETA: 486m 28s
# [253/11880 | 2.13%] 019015.jpg vs 028776.jpg | OpenFace | mtcnn | Metric: cosine | ETA: 484m 43s
# [254/11880 | 2.14%] 019015.jpg vs 028776.jpg | OpenFace | mtcnn | Metric: euclidean | ETA: 483m 10s
# [255/11880 | 2.15%] 019015.jpg vs 028776.jpg | OpenFace | retinaface | Metric: cosine | ETA: 481m 37s
# [256/11880 | 2.15%] 019015.jpg vs 028776.jpg | OpenFace | retinaface | Metric: euclidean | ETA: 485m 54s
# [257/11880 | 2.16%] 019015.jpg vs 028776.jpg | ArcFace | opencv | Metric: cosine | ETA: 490m 26s
#   [x] GAGAL: Exception while processing img1_path
# [258/11880 | 2.17%] 019015.jpg vs 028776.jpg | ArcFace | opencv | Metric: euclidean | ETA: 488m 31s
#   [x] GAGAL: Exception while processing img1_path
# [259/11880 | 2.18%] 019015.jpg vs 028776.jpg | ArcFace | ssd | Metric: cosine | ETA: 486m 35s
# [260/11880 | 2.19%] 019015.jpg vs 028776.jpg | ArcFace | ssd | Metric: euclidean | ETA: 485m 2s
# [261/11880 | 2.20%] 019015.jpg vs 028776.jpg | ArcFace | mtcnn | Metric: cosine | ETA: 483m 29s
# [262/11880 | 2.21%] 019015.jpg vs 028776.jpg | ArcFace | mtcnn | Metric: euclidean | ETA: 482m 7s
# [263/11880 | 2.21%] 019015.jpg vs 028776.jpg | ArcFace | retinaface | Metric: cosine | ETA: 480m 42s
# [264/11880 | 2.22%] 019015.jpg vs 028776.jpg | ArcFace | retinaface | Metric: euclidean | ETA: 485m 18s
# [265/11880 | 2.23%] 047098.jpg vs 070510.jpg | Facenet | opencv | Metric: cosine | ETA: 489m 31s
# [266/11880 | 2.24%] 047098.jpg vs 070510.jpg | Facenet | opencv | Metric: euclidean | ETA: 488m 3s
# [267/11880 | 2.25%] 047098.jpg vs 070510.jpg | Facenet | ssd | Metric: cosine | ETA: 486m 35s
# [268/11880 | 2.26%] 047098.jpg vs 070510.jpg | Facenet | ssd | Metric: euclidean | ETA: 485m 8s
# [269/11880 | 2.26%] 047098.jpg vs 070510.jpg | Facenet | mtcnn | Metric: cosine | ETA: 483m 42s
# [270/11880 | 2.27%] 047098.jpg vs 070510.jpg | Facenet | mtcnn | Metric: euclidean | ETA: 482m 25s
# [271/11880 | 2.28%] 047098.jpg vs 070510.jpg | Facenet | retinaface | Metric: cosine | ETA: 481m 8s
# [272/11880 | 2.29%] 047098.jpg vs 070510.jpg | Facenet | retinaface | Metric: euclidean | ETA: 485m 20s
# [273/11880 | 2.30%] 047098.jpg vs 070510.jpg | OpenFace | opencv | Metric: cosine | ETA: 489m 24s
# [274/11880 | 2.31%] 047098.jpg vs 070510.jpg | OpenFace | opencv | Metric: euclidean | ETA: 487m 45s
# [275/11880 | 2.31%] 047098.jpg vs 070510.jpg | OpenFace | ssd | Metric: cosine | ETA: 486m 7s
# [276/11880 | 2.32%] 047098.jpg vs 070510.jpg | OpenFace | ssd | Metric: euclidean | ETA: 484m 30s
# [277/11880 | 2.33%] 047098.jpg vs 070510.jpg | OpenFace | mtcnn | Metric: cosine | ETA: 482m 54s
# [278/11880 | 2.34%] 047098.jpg vs 070510.jpg | OpenFace | mtcnn | Metric: euclidean | ETA: 481m 26s
# [279/11880 | 2.35%] 047098.jpg vs 070510.jpg | OpenFace | retinaface | Metric: cosine | ETA: 479m 58s
# [280/11880 | 2.36%] 047098.jpg vs 070510.jpg | OpenFace | retinaface | Metric: euclidean | ETA: 483m 51s
# [281/11880 | 2.37%] 047098.jpg vs 070510.jpg | ArcFace | opencv | Metric: cosine | ETA: 487m 37s
# [282/11880 | 2.37%] 047098.jpg vs 070510.jpg | ArcFace | opencv | Metric: euclidean | ETA: 486m 8s
# [283/11880 | 2.38%] 047098.jpg vs 070510.jpg | ArcFace | ssd | Metric: cosine | ETA: 484m 40s
# [284/11880 | 2.39%] 047098.jpg vs 070510.jpg | ArcFace | ssd | Metric: euclidean | ETA: 483m 14s
# [285/11880 | 2.40%] 047098.jpg vs 070510.jpg | ArcFace | mtcnn | Metric: cosine | ETA: 481m 48s
# [286/11880 | 2.41%] 047098.jpg vs 070510.jpg | ArcFace | mtcnn | Metric: euclidean | ETA: 480m 30s
# [287/11880 | 2.42%] 047098.jpg vs 070510.jpg | ArcFace | retinaface | Metric: cosine | ETA: 479m 13s
# [288/11880 | 2.42%] 047098.jpg vs 070510.jpg | ArcFace | retinaface | Metric: euclidean | ETA: 483m 3s
# [289/11880 | 2.43%] 010516.jpg vs 039987.jpg | Facenet | opencv | Metric: cosine | ETA: 486m 52s
#   [x] GAGAL: Exception while processing img1_path
# [290/11880 | 2.44%] 010516.jpg vs 039987.jpg | Facenet | opencv | Metric: euclidean | ETA: 485m 10s
#   [x] GAGAL: Exception while processing img1_path
# [291/11880 | 2.45%] 010516.jpg vs 039987.jpg | Facenet | ssd | Metric: cosine | ETA: 483m 28s
# [292/11880 | 2.46%] 010516.jpg vs 039987.jpg | Facenet | ssd | Metric: euclidean | ETA: 482m 10s
# [293/11880 | 2.47%] 010516.jpg vs 039987.jpg | Facenet | mtcnn | Metric: cosine | ETA: 480m 52s
# [294/11880 | 2.47%] 010516.jpg vs 039987.jpg | Facenet | mtcnn | Metric: euclidean | ETA: 479m 41s
# [295/11880 | 2.48%] 010516.jpg vs 039987.jpg | Facenet | retinaface | Metric: cosine | ETA: 478m 29s
# [296/11880 | 2.49%] 010516.jpg vs 039987.jpg | Facenet | retinaface | Metric: euclidean | ETA: 482m 27s
# [297/11880 | 2.50%] 010516.jpg vs 039987.jpg | OpenFace | opencv | Metric: cosine | ETA: 486m 35s
#   [x] GAGAL: Exception while processing img1_path
# [298/11880 | 2.51%] 010516.jpg vs 039987.jpg | OpenFace | opencv | Metric: euclidean | ETA: 484m 55s
#   [x] GAGAL: Exception while processing img1_path
# [299/11880 | 2.52%] 010516.jpg vs 039987.jpg | OpenFace | ssd | Metric: cosine | ETA: 483m 16s
# [300/11880 | 2.53%] 010516.jpg vs 039987.jpg | OpenFace | ssd | Metric: euclidean | ETA: 481m 49s
# [301/11880 | 2.53%] 010516.jpg vs 039987.jpg | OpenFace | mtcnn | Metric: cosine | ETA: 480m 23s
# [302/11880 | 2.54%] 010516.jpg vs 039987.jpg | OpenFace | mtcnn | Metric: euclidean | ETA: 479m 4s
# [303/11880 | 2.55%] 010516.jpg vs 039987.jpg | OpenFace | retinaface | Metric: cosine | ETA: 477m 44s
# [304/11880 | 2.56%] 010516.jpg vs 039987.jpg | OpenFace | retinaface | Metric: euclidean | ETA: 481m 31s
# [305/11880 | 2.57%] 010516.jpg vs 039987.jpg | ArcFace | opencv | Metric: cosine | ETA: 485m 9s
#   [x] GAGAL: Exception while processing img1_path
# [306/11880 | 2.58%] 010516.jpg vs 039987.jpg | ArcFace | opencv | Metric: euclidean | ETA: 483m 32s
#   [x] GAGAL: Exception while processing img1_path
# [307/11880 | 2.58%] 010516.jpg vs 039987.jpg | ArcFace | ssd | Metric: cosine | ETA: 481m 56s
# [308/11880 | 2.59%] 010516.jpg vs 039987.jpg | ArcFace | ssd | Metric: euclidean | ETA: 480m 36s
# [309/11880 | 2.60%] 010516.jpg vs 039987.jpg | ArcFace | mtcnn | Metric: cosine | ETA: 479m 16s
# [310/11880 | 2.61%] 010516.jpg vs 039987.jpg | ArcFace | mtcnn | Metric: euclidean | ETA: 478m 4s
# [311/11880 | 2.62%] 010516.jpg vs 039987.jpg | ArcFace | retinaface | Metric: cosine | ETA: 476m 52s
# [312/11880 | 2.63%] 010516.jpg vs 039987.jpg | ArcFace | retinaface | Metric: euclidean | ETA: 480m 43s
# [313/11880 | 2.63%] 012823.jpg vs 019907.jpg | Facenet | opencv | Metric: cosine | ETA: 484m 28s
# [314/11880 | 2.64%] 012823.jpg vs 019907.jpg | Facenet | opencv | Metric: euclidean | ETA: 483m 24s
# [315/11880 | 2.65%] 012823.jpg vs 019907.jpg | Facenet | ssd | Metric: cosine | ETA: 482m 20s
# [316/11880 | 2.66%] 012823.jpg vs 019907.jpg | Facenet | ssd | Metric: euclidean | ETA: 481m 7s
# [317/11880 | 2.67%] 012823.jpg vs 019907.jpg | Facenet | mtcnn | Metric: cosine | ETA: 479m 56s
# [318/11880 | 2.68%] 012823.jpg vs 019907.jpg | Facenet | mtcnn | Metric: euclidean | ETA: 478m 52s
# [319/11880 | 2.69%] 012823.jpg vs 019907.jpg | Facenet | retinaface | Metric: cosine | ETA: 477m 47s
# [320/11880 | 2.69%] 012823.jpg vs 019907.jpg | Facenet | retinaface | Metric: euclidean | ETA: 481m 18s
# [321/11880 | 2.70%] 012823.jpg vs 019907.jpg | OpenFace | opencv | Metric: cosine | ETA: 484m 49s
# [322/11880 | 2.71%] 012823.jpg vs 019907.jpg | OpenFace | opencv | Metric: euclidean | ETA: 483m 29s
# [323/11880 | 2.72%] 012823.jpg vs 019907.jpg | OpenFace | ssd | Metric: cosine | ETA: 482m 10s
# [324/11880 | 2.73%] 012823.jpg vs 019907.jpg | OpenFace | ssd | Metric: euclidean | ETA: 480m 48s
# [325/11880 | 2.74%] 012823.jpg vs 019907.jpg | OpenFace | mtcnn | Metric: cosine | ETA: 479m 27s
# [326/11880 | 2.74%] 012823.jpg vs 019907.jpg | OpenFace | mtcnn | Metric: euclidean | ETA: 478m 14s
# [327/11880 | 2.75%] 012823.jpg vs 019907.jpg | OpenFace | retinaface | Metric: cosine | ETA: 477m 1s
# [328/11880 | 2.76%] 012823.jpg vs 019907.jpg | OpenFace | retinaface | Metric: euclidean | ETA: 480m 17s
# [329/11880 | 2.77%] 012823.jpg vs 019907.jpg | ArcFace | opencv | Metric: cosine | ETA: 483m 48s
# [330/11880 | 2.78%] 012823.jpg vs 019907.jpg | ArcFace | opencv | Metric: euclidean | ETA: 482m 41s
# [331/11880 | 2.79%] 012823.jpg vs 019907.jpg | ArcFace | ssd | Metric: cosine | ETA: 481m 34s
# [332/11880 | 2.79%] 012823.jpg vs 019907.jpg | ArcFace | ssd | Metric: euclidean | ETA: 480m 21s
# [333/11880 | 2.80%] 012823.jpg vs 019907.jpg | ArcFace | mtcnn | Metric: cosine | ETA: 479m 9s
# [334/11880 | 2.81%] 012823.jpg vs 019907.jpg | ArcFace | mtcnn | Metric: euclidean | ETA: 478m 4s
# [335/11880 | 2.82%] 012823.jpg vs 019907.jpg | ArcFace | retinaface | Metric: cosine | ETA: 476m 59s
# [336/11880 | 2.83%] 012823.jpg vs 019907.jpg | ArcFace | retinaface | Metric: euclidean | ETA: 480m 19s
# [337/11880 | 2.84%] 029583.jpg vs 041166.jpg | Facenet | opencv | Metric: cosine | ETA: 483m 38s
# [338/11880 | 2.85%] 029583.jpg vs 041166.jpg | Facenet | opencv | Metric: euclidean | ETA: 482m 32s
# [339/11880 | 2.85%] 029583.jpg vs 041166.jpg | Facenet | ssd | Metric: cosine | ETA: 481m 25s
# [340/11880 | 2.86%] 029583.jpg vs 041166.jpg | Facenet | ssd | Metric: euclidean | ETA: 480m 18s
# [341/11880 | 2.87%] 029583.jpg vs 041166.jpg | Facenet | mtcnn | Metric: cosine | ETA: 479m 12s
# [342/11880 | 2.88%] 029583.jpg vs 041166.jpg | Facenet | mtcnn | Metric: euclidean | ETA: 478m 14s
# [343/11880 | 2.89%] 029583.jpg vs 041166.jpg | Facenet | retinaface | Metric: cosine | ETA: 477m 14s
# [344/11880 | 2.90%] 029583.jpg vs 041166.jpg | Facenet | retinaface | Metric: euclidean | ETA: 480m 31s
# [345/11880 | 2.90%] 029583.jpg vs 041166.jpg | OpenFace | opencv | Metric: cosine | ETA: 483m 50s
# [346/11880 | 2.91%] 029583.jpg vs 041166.jpg | OpenFace | opencv | Metric: euclidean | ETA: 482m 33s
# [347/11880 | 2.92%] 029583.jpg vs 041166.jpg | OpenFace | ssd | Metric: cosine | ETA: 481m 16s
# [348/11880 | 2.93%] 029583.jpg vs 041166.jpg | OpenFace | ssd | Metric: euclidean | ETA: 480m 0s
# [349/11880 | 2.94%] 029583.jpg vs 041166.jpg | OpenFace | mtcnn | Metric: cosine | ETA: 478m 45s
# [350/11880 | 2.95%] 029583.jpg vs 041166.jpg | OpenFace | mtcnn | Metric: euclidean | ETA: 477m 34s
# [351/11880 | 2.95%] 029583.jpg vs 041166.jpg | OpenFace | retinaface | Metric: cosine | ETA: 476m 25s
# [352/11880 | 2.96%] 029583.jpg vs 041166.jpg | OpenFace | retinaface | Metric: euclidean | ETA: 479m 31s
# [353/11880 | 2.97%] 029583.jpg vs 041166.jpg | ArcFace | opencv | Metric: cosine | ETA: 482m 34s
# [354/11880 | 2.98%] 029583.jpg vs 041166.jpg | ArcFace | opencv | Metric: euclidean | ETA: 481m 23s
# [355/11880 | 2.99%] 029583.jpg vs 041166.jpg | ArcFace | ssd | Metric: cosine | ETA: 480m 13s
# [356/11880 | 3.00%] 029583.jpg vs 041166.jpg | ArcFace | ssd | Metric: euclidean | ETA: 479m 5s
# [357/11880 | 3.01%] 029583.jpg vs 041166.jpg | ArcFace | mtcnn | Metric: cosine | ETA: 477m 56s
# [358/11880 | 3.01%] 029583.jpg vs 041166.jpg | ArcFace | mtcnn | Metric: euclidean | ETA: 476m 53s
# [359/11880 | 3.02%] 029583.jpg vs 041166.jpg | ArcFace | retinaface | Metric: cosine | ETA: 475m 50s
# [360/11880 | 3.03%] 029583.jpg vs 041166.jpg | ArcFace | retinaface | Metric: euclidean | ETA: 478m 58s
# [361/11880 | 3.04%] 066448.jpg vs 068314.jpg | Facenet | opencv | Metric: cosine | ETA: 482m 6s
# [362/11880 | 3.05%] 066448.jpg vs 068314.jpg | Facenet | opencv | Metric: euclidean | ETA: 481m 1s
# [363/11880 | 3.06%] 066448.jpg vs 068314.jpg | Facenet | ssd | Metric: cosine | ETA: 479m 57s
# [364/11880 | 3.06%] 066448.jpg vs 068314.jpg | Facenet | ssd | Metric: euclidean | ETA: 478m 53s
# [365/11880 | 3.07%] 066448.jpg vs 068314.jpg | Facenet | mtcnn | Metric: cosine | ETA: 477m 49s
# [366/11880 | 3.08%] 066448.jpg vs 068314.jpg | Facenet | mtcnn | Metric: euclidean | ETA: 476m 50s
# [367/11880 | 3.09%] 066448.jpg vs 068314.jpg | Facenet | retinaface | Metric: cosine | ETA: 475m 53s
# [368/11880 | 3.10%] 066448.jpg vs 068314.jpg | Facenet | retinaface | Metric: euclidean | ETA: 479m 5s
# [369/11880 | 3.11%] 066448.jpg vs 068314.jpg | OpenFace | opencv | Metric: cosine | ETA: 482m 17s
# [370/11880 | 3.11%] 066448.jpg vs 068314.jpg | OpenFace | opencv | Metric: euclidean | ETA: 481m 4s
# [371/11880 | 3.12%] 066448.jpg vs 068314.jpg | OpenFace | ssd | Metric: cosine | ETA: 479m 52s
# [372/11880 | 3.13%] 066448.jpg vs 068314.jpg | OpenFace | ssd | Metric: euclidean | ETA: 478m 41s
# [373/11880 | 3.14%] 066448.jpg vs 068314.jpg | OpenFace | mtcnn | Metric: cosine | ETA: 477m 30s
# [374/11880 | 3.15%] 066448.jpg vs 068314.jpg | OpenFace | mtcnn | Metric: euclidean | ETA: 476m 25s
# [375/11880 | 3.16%] 066448.jpg vs 068314.jpg | OpenFace | retinaface | Metric: cosine | ETA: 475m 18s
# [376/11880 | 3.16%] 066448.jpg vs 068314.jpg | OpenFace | retinaface | Metric: euclidean | ETA: 478m 17s
# [377/11880 | 3.17%] 066448.jpg vs 068314.jpg | ArcFace | opencv | Metric: cosine | ETA: 481m 20s
# [378/11880 | 3.18%] 066448.jpg vs 068314.jpg | ArcFace | opencv | Metric: euclidean | ETA: 480m 13s
# [379/11880 | 3.19%] 066448.jpg vs 068314.jpg | ArcFace | ssd | Metric: cosine | ETA: 479m 8s
# [380/11880 | 3.20%] 066448.jpg vs 068314.jpg | ArcFace | ssd | Metric: euclidean | ETA: 478m 3s
# [381/11880 | 3.21%] 066448.jpg vs 068314.jpg | ArcFace | mtcnn | Metric: cosine | ETA: 476m 58s
# [382/11880 | 3.22%] 066448.jpg vs 068314.jpg | ArcFace | mtcnn | Metric: euclidean | ETA: 475m 58s
# [383/11880 | 3.22%] 066448.jpg vs 068314.jpg | ArcFace | retinaface | Metric: cosine | ETA: 475m 0s
# [384/11880 | 3.23%] 066448.jpg vs 068314.jpg | ArcFace | retinaface | Metric: euclidean | ETA: 477m 55s
# [385/11880 | 3.24%] 000004.jpg vs 000008.jpg | Facenet | opencv | Metric: cosine | ETA: 480m 43s
#   [x] GAGAL: Exception while processing img1_path
# [386/11880 | 3.25%] 000004.jpg vs 000008.jpg | Facenet | opencv | Metric: euclidean | ETA: 479m 27s
#   [x] GAGAL: Exception while processing img1_path
# [387/11880 | 3.26%] 000004.jpg vs 000008.jpg | Facenet | ssd | Metric: cosine | ETA: 478m 10s
# [388/11880 | 3.27%] 000004.jpg vs 000008.jpg | Facenet | ssd | Metric: euclidean | ETA: 477m 12s
# [389/11880 | 3.27%] 000004.jpg vs 000008.jpg | Facenet | mtcnn | Metric: cosine | ETA: 476m 14s
# [390/11880 | 3.28%] 000004.jpg vs 000008.jpg | Facenet | mtcnn | Metric: euclidean | ETA: 475m 22s
# [391/11880 | 3.29%] 000004.jpg vs 000008.jpg | Facenet | retinaface | Metric: cosine | ETA: 474m 30s
# [392/11880 | 3.30%] 000004.jpg vs 000008.jpg | Facenet | retinaface | Metric: euclidean | ETA: 477m 28s
# [393/11880 | 3.31%] 000004.jpg vs 000008.jpg | OpenFace | opencv | Metric: cosine | ETA: 480m 17s
#   [x] GAGAL: Exception while processing img1_path
# [394/11880 | 3.32%] 000004.jpg vs 000008.jpg | OpenFace | opencv | Metric: euclidean | ETA: 479m 2s
#   [x] GAGAL: Exception while processing img1_path
# [395/11880 | 3.32%] 000004.jpg vs 000008.jpg | OpenFace | ssd | Metric: cosine | ETA: 477m 47s
# [396/11880 | 3.33%] 000004.jpg vs 000008.jpg | OpenFace | ssd | Metric: euclidean | ETA: 476m 40s
# [397/11880 | 3.34%] 000004.jpg vs 000008.jpg | OpenFace | mtcnn | Metric: cosine | ETA: 475m 33s
# [398/11880 | 3.35%] 000004.jpg vs 000008.jpg | OpenFace | mtcnn | Metric: euclidean | ETA: 474m 33s
# [399/11880 | 3.36%] 000004.jpg vs 000008.jpg | OpenFace | retinaface | Metric: cosine | ETA: 473m 32s
# [400/11880 | 3.37%] 000004.jpg vs 000008.jpg | OpenFace | retinaface | Metric: euclidean | ETA: 476m 8s
# [401/11880 | 3.38%] 000004.jpg vs 000008.jpg | ArcFace | opencv | Metric: cosine | ETA: 478m 47s
#   [x] GAGAL: Exception while processing img1_path
# [402/11880 | 3.38%] 000004.jpg vs 000008.jpg | ArcFace | opencv | Metric: euclidean | ETA: 477m 33s
#   [x] GAGAL: Exception while processing img1_path
# [403/11880 | 3.39%] 000004.jpg vs 000008.jpg | ArcFace | ssd | Metric: cosine | ETA: 476m 20s
# [404/11880 | 3.40%] 000004.jpg vs 000008.jpg | ArcFace | ssd | Metric: euclidean | ETA: 475m 20s
# [405/11880 | 3.41%] 000004.jpg vs 000008.jpg | ArcFace | mtcnn | Metric: cosine | ETA: 474m 19s
# [406/11880 | 3.42%] 000004.jpg vs 000008.jpg | ArcFace | mtcnn | Metric: euclidean | ETA: 473m 24s
# [407/11880 | 3.43%] 000004.jpg vs 000008.jpg | ArcFace | retinaface | Metric: cosine | ETA: 472m 30s
# [408/11880 | 3.43%] 000004.jpg vs 000008.jpg | ArcFace | retinaface | Metric: euclidean | ETA: 475m 8s
# [409/11880 | 3.44%] 013676.jpg vs 030445.jpg | Facenet | opencv | Metric: cosine | ETA: 477m 9s
# [410/11880 | 3.45%] 013676.jpg vs 030445.jpg | Facenet | opencv | Metric: euclidean | ETA: 476m 7s
# [411/11880 | 3.46%] 013676.jpg vs 030445.jpg | Facenet | ssd | Metric: cosine | ETA: 475m 4s
# [412/11880 | 3.47%] 013676.jpg vs 030445.jpg | Facenet | ssd | Metric: euclidean | ETA: 474m 2s
# [413/11880 | 3.48%] 013676.jpg vs 030445.jpg | Facenet | mtcnn | Metric: cosine | ETA: 473m 1s
# [414/11880 | 3.48%] 013676.jpg vs 030445.jpg | Facenet | mtcnn | Metric: euclidean | ETA: 472m 3s
# [415/11880 | 3.49%] 013676.jpg vs 030445.jpg | Facenet | retinaface | Metric: cosine | ETA: 471m 6s
# [416/11880 | 3.50%] 013676.jpg vs 030445.jpg | Facenet | retinaface | Metric: euclidean | ETA: 473m 2s
# [417/11880 | 3.51%] 013676.jpg vs 030445.jpg | OpenFace | opencv | Metric: cosine | ETA: 474m 58s
# [418/11880 | 3.52%] 013676.jpg vs 030445.jpg | OpenFace | opencv | Metric: euclidean | ETA: 473m 51s
# [419/11880 | 3.53%] 013676.jpg vs 030445.jpg | OpenFace | ssd | Metric: cosine | ETA: 472m 45s
# [420/11880 | 3.54%] 013676.jpg vs 030445.jpg | OpenFace | ssd | Metric: euclidean | ETA: 471m 40s
# [421/11880 | 3.54%] 013676.jpg vs 030445.jpg | OpenFace | mtcnn | Metric: cosine | ETA: 470m 34s
# [422/11880 | 3.55%] 013676.jpg vs 030445.jpg | OpenFace | mtcnn | Metric: euclidean | ETA: 469m 32s
# [423/11880 | 3.56%] 013676.jpg vs 030445.jpg | OpenFace | retinaface | Metric: cosine | ETA: 468m 31s
# [424/11880 | 3.57%] 013676.jpg vs 030445.jpg | OpenFace | retinaface | Metric: euclidean | ETA: 470m 20s
# [425/11880 | 3.58%] 013676.jpg vs 030445.jpg | ArcFace | opencv | Metric: cosine | ETA: 472m 11s
# [426/11880 | 3.59%] 013676.jpg vs 030445.jpg | ArcFace | opencv | Metric: euclidean | ETA: 471m 9s
# [427/11880 | 3.59%] 013676.jpg vs 030445.jpg | ArcFace | ssd | Metric: cosine | ETA: 470m 8s
# [428/11880 | 3.60%] 013676.jpg vs 030445.jpg | ArcFace | ssd | Metric: euclidean | ETA: 469m 7s
# [429/11880 | 3.61%] 013676.jpg vs 030445.jpg | ArcFace | mtcnn | Metric: cosine | ETA: 468m 6s
# [430/11880 | 3.62%] 013676.jpg vs 030445.jpg | ArcFace | mtcnn | Metric: euclidean | ETA: 467m 9s
# [431/11880 | 3.63%] 013676.jpg vs 030445.jpg | ArcFace | retinaface | Metric: cosine | ETA: 466m 11s
# [432/11880 | 3.64%] 013676.jpg vs 030445.jpg | ArcFace | retinaface | Metric: euclidean | ETA: 468m 3s
# [433/11880 | 3.64%] 000003.jpg vs 033840.jpg | Facenet | opencv | Metric: cosine | ETA: 469m 52s
#   [x] GAGAL: Exception while processing img1_path
# [434/11880 | 3.65%] 000003.jpg vs 033840.jpg | Facenet | opencv | Metric: euclidean | ETA: 468m 45s
#   [x] GAGAL: Exception while processing img1_path
# [435/11880 | 3.66%] 000003.jpg vs 033840.jpg | Facenet | ssd | Metric: cosine | ETA: 467m 39s
# [436/11880 | 3.67%] 000003.jpg vs 033840.jpg | Facenet | ssd | Metric: euclidean | ETA: 466m 41s
# [437/11880 | 3.68%] 000003.jpg vs 033840.jpg | Facenet | mtcnn | Metric: cosine | ETA: 465m 44s
# [438/11880 | 3.69%] 000003.jpg vs 033840.jpg | Facenet | mtcnn | Metric: euclidean | ETA: 464m 50s
# [439/11880 | 3.70%] 000003.jpg vs 033840.jpg | Facenet | retinaface | Metric: cosine | ETA: 463m 57s
# [440/11880 | 3.70%] 000003.jpg vs 033840.jpg | Facenet | retinaface | Metric: euclidean | ETA: 465m 53s
# [441/11880 | 3.71%] 000003.jpg vs 033840.jpg | OpenFace | opencv | Metric: cosine | ETA: 467m 43s
#   [x] GAGAL: Exception while processing img1_path
# [442/11880 | 3.72%] 000003.jpg vs 033840.jpg | OpenFace | opencv | Metric: euclidean | ETA: 466m 37s
#   [x] GAGAL: Exception while processing img1_path
# [443/11880 | 3.73%] 000003.jpg vs 033840.jpg | OpenFace | ssd | Metric: cosine | ETA: 465m 31s
# [444/11880 | 3.74%] 000003.jpg vs 033840.jpg | OpenFace | ssd | Metric: euclidean | ETA: 464m 30s
# [445/11880 | 3.75%] 000003.jpg vs 033840.jpg | OpenFace | mtcnn | Metric: cosine | ETA: 463m 30s
# [446/11880 | 3.75%] 000003.jpg vs 033840.jpg | OpenFace | mtcnn | Metric: euclidean | ETA: 462m 32s
# [447/11880 | 3.76%] 000003.jpg vs 033840.jpg | OpenFace | retinaface | Metric: cosine | ETA: 461m 35s
# [448/11880 | 3.77%] 000003.jpg vs 033840.jpg | OpenFace | retinaface | Metric: euclidean | ETA: 463m 19s
# [449/11880 | 3.78%] 000003.jpg vs 033840.jpg | ArcFace | opencv | Metric: cosine | ETA: 465m 6s
#   [x] GAGAL: Exception while processing img1_path
# [450/11880 | 3.79%] 000003.jpg vs 033840.jpg | ArcFace | opencv | Metric: euclidean | ETA: 464m 2s
#   [x] GAGAL: Exception while processing img1_path
# [451/11880 | 3.80%] 000003.jpg vs 033840.jpg | ArcFace | ssd | Metric: cosine | ETA: 462m 58s
# [452/11880 | 3.80%] 000003.jpg vs 033840.jpg | ArcFace | ssd | Metric: euclidean | ETA: 462m 1s
# [453/11880 | 3.81%] 000003.jpg vs 033840.jpg | ArcFace | mtcnn | Metric: cosine | ETA: 461m 5s
# [454/11880 | 3.82%] 000003.jpg vs 033840.jpg | ArcFace | mtcnn | Metric: euclidean | ETA: 460m 12s
# [455/11880 | 3.83%] 000003.jpg vs 033840.jpg | ArcFace | retinaface | Metric: cosine | ETA: 459m 18s
# [456/11880 | 3.84%] 000003.jpg vs 033840.jpg | ArcFace | retinaface | Metric: euclidean | ETA: 461m 4s
# [457/11880 | 3.85%] 028776.jpg vs 057124.jpg | Facenet | opencv | Metric: cosine | ETA: 462m 49s
#   [x] GAGAL: Exception while processing img1_path
# [458/11880 | 3.86%] 028776.jpg vs 057124.jpg | Facenet | opencv | Metric: euclidean | ETA: 461m 47s
#   [x] GAGAL: Exception while processing img1_path
# [459/11880 | 3.86%] 028776.jpg vs 057124.jpg | Facenet | ssd | Metric: cosine | ETA: 460m 44s
# [460/11880 | 3.87%] 028776.jpg vs 057124.jpg | Facenet | ssd | Metric: euclidean | ETA: 459m 51s
# [461/11880 | 3.88%] 028776.jpg vs 057124.jpg | Facenet | mtcnn | Metric: cosine | ETA: 458m 58s
# [462/11880 | 3.89%] 028776.jpg vs 057124.jpg | Facenet | mtcnn | Metric: euclidean | ETA: 458m 7s
# [463/11880 | 3.90%] 028776.jpg vs 057124.jpg | Facenet | retinaface | Metric: cosine | ETA: 457m 16s
# [464/11880 | 3.91%] 028776.jpg vs 057124.jpg | Facenet | retinaface | Metric: euclidean | ETA: 459m 1s
# [465/11880 | 3.91%] 028776.jpg vs 057124.jpg | OpenFace | opencv | Metric: cosine | ETA: 460m 46s
#   [x] GAGAL: Exception while processing img1_path
# [466/11880 | 3.92%] 028776.jpg vs 057124.jpg | OpenFace | opencv | Metric: euclidean | ETA: 459m 45s
#   [x] GAGAL: Exception while processing img1_path
# ...
# [11731/11880 | 98.75%] 030445.jpg vs 032973.jpg | ArcFace | ssd | Metric: cosine | ETA: 4m 49s
# [11732/11880 | 98.75%] 030445.jpg vs 032973.jpg | ArcFace | ssd | Metric: euclidean | ETA: 4m 47s
# [11733/11880 | 98.76%] 030445.jpg vs 032973.jpg | ArcFace | mtcnn | Metric: cosine | ETA: 4m 45s
# [11734/11880 | 98.77%] 030445.jpg vs 032973.jpg | ArcFace | mtcnn | Metric: euclidean | ETA: 4m 43s
# [11735/11880 | 98.78%] 030445.jpg vs 032973.jpg | ArcFace | retinaface | Metric: cosine | ETA: 4m 41s
# [11736/11880 | 98.79%] 030445.jpg vs 032973.jpg | ArcFace | retinaface | Metric: euclidean | ETA: 4m 39s
# [11737/11880 | 98.80%] 025244.jpg vs 039393.jpg | Facenet | opencv | Metric: cosine | ETA: 4m 37s
# [11738/11880 | 98.80%] 025244.jpg vs 039393.jpg | Facenet | opencv | Metric: euclidean | ETA: 4m 35s
# [11739/11880 | 98.81%] 025244.jpg vs 039393.jpg | Facenet | ssd | Metric: cosine | ETA: 4m 33s
# [11740/11880 | 98.82%] 025244.jpg vs 039393.jpg | Facenet | ssd | Metric: euclidean | ETA: 4m 31s
# [11741/11880 | 98.83%] 025244.jpg vs 039393.jpg | Facenet | mtcnn | Metric: cosine | ETA: 4m 29s
# [11742/11880 | 98.84%] 025244.jpg vs 039393.jpg | Facenet | mtcnn | Metric: euclidean | ETA: 4m 27s
# [11743/11880 | 98.85%] 025244.jpg vs 039393.jpg | Facenet | retinaface | Metric: cosine | ETA: 4m 25s
# [11744/11880 | 98.86%] 025244.jpg vs 039393.jpg | Facenet | retinaface | Metric: euclidean | ETA: 4m 23s
# [11745/11880 | 98.86%] 025244.jpg vs 039393.jpg | OpenFace | opencv | Metric: cosine | ETA: 4m 22s
# [11746/11880 | 98.87%] 025244.jpg vs 039393.jpg | OpenFace | opencv | Metric: euclidean | ETA: 4m 20s
# [11747/11880 | 98.88%] 025244.jpg vs 039393.jpg | OpenFace | ssd | Metric: cosine | ETA: 4m 18s
# [11748/11880 | 98.89%] 025244.jpg vs 039393.jpg | OpenFace | ssd | Metric: euclidean | ETA: 4m 16s
# [11749/11880 | 98.90%] 025244.jpg vs 039393.jpg | OpenFace | mtcnn | Metric: cosine | ETA: 4m 14s
# [11750/11880 | 98.91%] 025244.jpg vs 039393.jpg | OpenFace | mtcnn | Metric: euclidean | ETA: 4m 12s
# [11751/11880 | 98.91%] 025244.jpg vs 039393.jpg | OpenFace | retinaface | Metric: cosine | ETA: 4m 10s
# [11752/11880 | 98.92%] 025244.jpg vs 039393.jpg | OpenFace | retinaface | Metric: euclidean | ETA: 4m 8s
# [11753/11880 | 98.93%] 025244.jpg vs 039393.jpg | ArcFace | opencv | Metric: cosine | ETA: 4m 6s
# [11754/11880 | 98.94%] 025244.jpg vs 039393.jpg | ArcFace | opencv | Metric: euclidean | ETA: 4m 4s
# [11755/11880 | 98.95%] 025244.jpg vs 039393.jpg | ArcFace | ssd | Metric: cosine | ETA: 4m 2s
# [11756/11880 | 98.96%] 025244.jpg vs 039393.jpg | ArcFace | ssd | Metric: euclidean | ETA: 4m 0s
# [11757/11880 | 98.96%] 025244.jpg vs 039393.jpg | ArcFace | mtcnn | Metric: cosine | ETA: 3m 58s
# [11758/11880 | 98.97%] 025244.jpg vs 039393.jpg | ArcFace | mtcnn | Metric: euclidean | ETA: 3m 56s
# [11759/11880 | 98.98%] 025244.jpg vs 039393.jpg | ArcFace | retinaface | Metric: cosine | ETA: 3m 54s
# [11760/11880 | 98.99%] 025244.jpg vs 039393.jpg | ArcFace | retinaface | Metric: euclidean | ETA: 3m 52s
# [11761/11880 | 99.00%] 038160.jpg vs 047098.jpg | Facenet | opencv | Metric: cosine | ETA: 3m 50s
# [11762/11880 | 99.01%] 038160.jpg vs 047098.jpg | Facenet | opencv | Metric: euclidean | ETA: 3m 49s
# [11763/11880 | 99.02%] 038160.jpg vs 047098.jpg | Facenet | ssd | Metric: cosine | ETA: 3m 47s
# [11764/11880 | 99.02%] 038160.jpg vs 047098.jpg | Facenet | ssd | Metric: euclidean | ETA: 3m 45s
# [11765/11880 | 99.03%] 038160.jpg vs 047098.jpg | Facenet | mtcnn | Metric: cosine | ETA: 3m 43s
# [11766/11880 | 99.04%] 038160.jpg vs 047098.jpg | Facenet | mtcnn | Metric: euclidean | ETA: 3m 41s
# [11767/11880 | 99.05%] 038160.jpg vs 047098.jpg | Facenet | retinaface | Metric: cosine | ETA: 3m 39s
# [11768/11880 | 99.06%] 038160.jpg vs 047098.jpg | Facenet | retinaface | Metric: euclidean | ETA: 3m 37s
# [11769/11880 | 99.07%] 038160.jpg vs 047098.jpg | OpenFace | opencv | Metric: cosine | ETA: 3m 35s
# [11770/11880 | 99.07%] 038160.jpg vs 047098.jpg | OpenFace | opencv | Metric: euclidean | ETA: 3m 33s
# [11771/11880 | 99.08%] 038160.jpg vs 047098.jpg | OpenFace | ssd | Metric: cosine | ETA: 3m 31s
# [11772/11880 | 99.09%] 038160.jpg vs 047098.jpg | OpenFace | ssd | Metric: euclidean | ETA: 3m 29s
# [11773/11880 | 99.10%] 038160.jpg vs 047098.jpg | OpenFace | mtcnn | Metric: cosine | ETA: 3m 27s
# [11774/11880 | 99.11%] 038160.jpg vs 047098.jpg | OpenFace | mtcnn | Metric: euclidean | ETA: 3m 25s
# [11775/11880 | 99.12%] 038160.jpg vs 047098.jpg | OpenFace | retinaface | Metric: cosine | ETA: 3m 23s
# [11776/11880 | 99.12%] 038160.jpg vs 047098.jpg | OpenFace | retinaface | Metric: euclidean | ETA: 3m 21s
# [11777/11880 | 99.13%] 038160.jpg vs 047098.jpg | ArcFace | opencv | Metric: cosine | ETA: 3m 19s
# [11778/11880 | 99.14%] 038160.jpg vs 047098.jpg | ArcFace | opencv | Metric: euclidean | ETA: 3m 17s
# [11779/11880 | 99.15%] 038160.jpg vs 047098.jpg | ArcFace | ssd | Metric: cosine | ETA: 3m 16s
# [11780/11880 | 99.16%] 038160.jpg vs 047098.jpg | ArcFace | ssd | Metric: euclidean | ETA: 3m 14s
# [11781/11880 | 99.17%] 038160.jpg vs 047098.jpg | ArcFace | mtcnn | Metric: cosine | ETA: 3m 12s
# [11782/11880 | 99.18%] 038160.jpg vs 047098.jpg | ArcFace | mtcnn | Metric: euclidean | ETA: 3m 10s
# [11783/11880 | 99.18%] 038160.jpg vs 047098.jpg | ArcFace | retinaface | Metric: cosine | ETA: 3m 8s
# [11784/11880 | 99.19%] 038160.jpg vs 047098.jpg | ArcFace | retinaface | Metric: euclidean | ETA: 3m 6s
# [11785/11880 | 99.20%] 004349.jpg vs 010516.jpg | Facenet | opencv | Metric: cosine | ETA: 3m 4s
#   [x] GAGAL: Exception while processing img2_path
# [11786/11880 | 99.21%] 004349.jpg vs 010516.jpg | Facenet | opencv | Metric: euclidean | ETA: 3m 2s
#   [x] GAGAL: Exception while processing img2_path
# [11787/11880 | 99.22%] 004349.jpg vs 010516.jpg | Facenet | ssd | Metric: cosine | ETA: 3m 0s
# [11788/11880 | 99.23%] 004349.jpg vs 010516.jpg | Facenet | ssd | Metric: euclidean | ETA: 2m 58s
# [11789/11880 | 99.23%] 004349.jpg vs 010516.jpg | Facenet | mtcnn | Metric: cosine | ETA: 2m 56s
# [11790/11880 | 99.24%] 004349.jpg vs 010516.jpg | Facenet | mtcnn | Metric: euclidean | ETA: 2m 54s
# [11791/11880 | 99.25%] 004349.jpg vs 010516.jpg | Facenet | retinaface | Metric: cosine | ETA: 2m 52s
# [11792/11880 | 99.26%] 004349.jpg vs 010516.jpg | Facenet | retinaface | Metric: euclidean | ETA: 2m 50s
# [11793/11880 | 99.27%] 004349.jpg vs 010516.jpg | OpenFace | opencv | Metric: cosine | ETA: 2m 48s
#   [x] GAGAL: Exception while processing img2_path
# [11794/11880 | 99.28%] 004349.jpg vs 010516.jpg | OpenFace | opencv | Metric: euclidean | ETA: 2m 46s
#   [x] GAGAL: Exception while processing img2_path
# [11795/11880 | 99.28%] 004349.jpg vs 010516.jpg | OpenFace | ssd | Metric: cosine | ETA: 2m 44s
# [11796/11880 | 99.29%] 004349.jpg vs 010516.jpg | OpenFace | ssd | Metric: euclidean | ETA: 2m 43s
# [11797/11880 | 99.30%] 004349.jpg vs 010516.jpg | OpenFace | mtcnn | Metric: cosine | ETA: 2m 41s
# [11798/11880 | 99.31%] 004349.jpg vs 010516.jpg | OpenFace | mtcnn | Metric: euclidean | ETA: 2m 39s
# [11799/11880 | 99.32%] 004349.jpg vs 010516.jpg | OpenFace | retinaface | Metric: cosine | ETA: 2m 37s
# [11800/11880 | 99.33%] 004349.jpg vs 010516.jpg | OpenFace | retinaface | Metric: euclidean | ETA: 2m 35s
# [11801/11880 | 99.34%] 004349.jpg vs 010516.jpg | ArcFace | opencv | Metric: cosine | ETA: 2m 33s
#   [x] GAGAL: Exception while processing img2_path
# [11802/11880 | 99.34%] 004349.jpg vs 010516.jpg | ArcFace | opencv | Metric: euclidean | ETA: 2m 31s
#   [x] GAGAL: Exception while processing img2_path
# [11803/11880 | 99.35%] 004349.jpg vs 010516.jpg | ArcFace | ssd | Metric: cosine | ETA: 2m 29s
# [11804/11880 | 99.36%] 004349.jpg vs 010516.jpg | ArcFace | ssd | Metric: euclidean | ETA: 2m 27s
# [11805/11880 | 99.37%] 004349.jpg vs 010516.jpg | ArcFace | mtcnn | Metric: cosine | ETA: 2m 25s
# [11806/11880 | 99.38%] 004349.jpg vs 010516.jpg | ArcFace | mtcnn | Metric: euclidean | ETA: 2m 23s
# [11807/11880 | 99.39%] 004349.jpg vs 010516.jpg | ArcFace | retinaface | Metric: cosine | ETA: 2m 21s
# [11808/11880 | 99.39%] 004349.jpg vs 010516.jpg | ArcFace | retinaface | Metric: euclidean | ETA: 2m 19s
# [11809/11880 | 99.40%] 000004.jpg vs 000005.jpg | Facenet | opencv | Metric: cosine | ETA: 2m 17s
#   [x] GAGAL: Exception while processing img1_path
# [11810/11880 | 99.41%] 000004.jpg vs 000005.jpg | Facenet | opencv | Metric: euclidean | ETA: 2m 15s
#   [x] GAGAL: Exception while processing img1_path
# [11811/11880 | 99.42%] 000004.jpg vs 000005.jpg | Facenet | ssd | Metric: cosine | ETA: 2m 13s
# [11812/11880 | 99.43%] 000004.jpg vs 000005.jpg | Facenet | ssd | Metric: euclidean | ETA: 2m 11s
# [11813/11880 | 99.44%] 000004.jpg vs 000005.jpg | Facenet | mtcnn | Metric: cosine | ETA: 2m 10s
# [11814/11880 | 99.44%] 000004.jpg vs 000005.jpg | Facenet | mtcnn | Metric: euclidean | ETA: 2m 8s
# [11815/11880 | 99.45%] 000004.jpg vs 000005.jpg | Facenet | retinaface | Metric: cosine | ETA: 2m 6s
# [11816/11880 | 99.46%] 000004.jpg vs 000005.jpg | Facenet | retinaface | Metric: euclidean | ETA: 2m 4s
# [11817/11880 | 99.47%] 000004.jpg vs 000005.jpg | OpenFace | opencv | Metric: cosine | ETA: 2m 2s
#   [x] GAGAL: Exception while processing img1_path
# [11818/11880 | 99.48%] 000004.jpg vs 000005.jpg | OpenFace | opencv | Metric: euclidean | ETA: 2m 0s
#   [x] GAGAL: Exception while processing img1_path
# [11819/11880 | 99.49%] 000004.jpg vs 000005.jpg | OpenFace | ssd | Metric: cosine | ETA: 1m 58s
# [11820/11880 | 99.49%] 000004.jpg vs 000005.jpg | OpenFace | ssd | Metric: euclidean | ETA: 1m 56s
# [11821/11880 | 99.50%] 000004.jpg vs 000005.jpg | OpenFace | mtcnn | Metric: cosine | ETA: 1m 54s
# [11822/11880 | 99.51%] 000004.jpg vs 000005.jpg | OpenFace | mtcnn | Metric: euclidean | ETA: 1m 52s
# [11823/11880 | 99.52%] 000004.jpg vs 000005.jpg | OpenFace | retinaface | Metric: cosine | ETA: 1m 50s
# [11824/11880 | 99.53%] 000004.jpg vs 000005.jpg | OpenFace | retinaface | Metric: euclidean | ETA: 1m 48s
# [11825/11880 | 99.54%] 000004.jpg vs 000005.jpg | ArcFace | opencv | Metric: cosine | ETA: 1m 46s
#   [x] GAGAL: Exception while processing img1_path
# [11826/11880 | 99.55%] 000004.jpg vs 000005.jpg | ArcFace | opencv | Metric: euclidean | ETA: 1m 44s
#   [x] GAGAL: Exception while processing img1_path
# [11827/11880 | 99.55%] 000004.jpg vs 000005.jpg | ArcFace | ssd | Metric: cosine | ETA: 1m 42s
# [11828/11880 | 99.56%] 000004.jpg vs 000005.jpg | ArcFace | ssd | Metric: euclidean | ETA: 1m 40s
# [11829/11880 | 99.57%] 000004.jpg vs 000005.jpg | ArcFace | mtcnn | Metric: cosine | ETA: 1m 38s
# [11830/11880 | 99.58%] 000004.jpg vs 000005.jpg | ArcFace | mtcnn | Metric: euclidean | ETA: 1m 37s
# [11831/11880 | 99.59%] 000004.jpg vs 000005.jpg | ArcFace | retinaface | Metric: cosine | ETA: 1m 35s
# [11832/11880 | 99.60%] 000004.jpg vs 000005.jpg | ArcFace | retinaface | Metric: euclidean | ETA: 1m 33s
# [11833/11880 | 99.60%] 010191.jpg vs 032973.jpg | Facenet | opencv | Metric: cosine | ETA: 1m 31s
#   [x] GAGAL: Exception while processing img1_path
# [11834/11880 | 99.61%] 010191.jpg vs 032973.jpg | Facenet | opencv | Metric: euclidean | ETA: 1m 29s
#   [x] GAGAL: Exception while processing img1_path
# [11835/11880 | 99.62%] 010191.jpg vs 032973.jpg | Facenet | ssd | Metric: cosine | ETA: 1m 27s
# [11836/11880 | 99.63%] 010191.jpg vs 032973.jpg | Facenet | ssd | Metric: euclidean | ETA: 1m 25s
# [11837/11880 | 99.64%] 010191.jpg vs 032973.jpg | Facenet | mtcnn | Metric: cosine | ETA: 1m 23s
# [11838/11880 | 99.65%] 010191.jpg vs 032973.jpg | Facenet | mtcnn | Metric: euclidean | ETA: 1m 21s
# [11839/11880 | 99.65%] 010191.jpg vs 032973.jpg | Facenet | retinaface | Metric: cosine | ETA: 1m 19s
# [11840/11880 | 99.66%] 010191.jpg vs 032973.jpg | Facenet | retinaface | Metric: euclidean | ETA: 1m 17s
# [11841/11880 | 99.67%] 010191.jpg vs 032973.jpg | OpenFace | opencv | Metric: cosine | ETA: 1m 15s
#   [x] GAGAL: Exception while processing img1_path
# [11842/11880 | 99.68%] 010191.jpg vs 032973.jpg | OpenFace | opencv | Metric: euclidean | ETA: 1m 13s
#   [x] GAGAL: Exception while processing img1_path
# [11843/11880 | 99.69%] 010191.jpg vs 032973.jpg | OpenFace | ssd | Metric: cosine | ETA: 1m 11s
# [11844/11880 | 99.70%] 010191.jpg vs 032973.jpg | OpenFace | ssd | Metric: euclidean | ETA: 1m 9s
# [11845/11880 | 99.71%] 010191.jpg vs 032973.jpg | OpenFace | mtcnn | Metric: cosine | ETA: 1m 7s
# [11846/11880 | 99.71%] 010191.jpg vs 032973.jpg | OpenFace | mtcnn | Metric: euclidean | ETA: 1m 5s
# [11847/11880 | 99.72%] 010191.jpg vs 032973.jpg | OpenFace | retinaface | Metric: cosine | ETA: 1m 4s
# [11848/11880 | 99.73%] 010191.jpg vs 032973.jpg | OpenFace | retinaface | Metric: euclidean | ETA: 1m 2s
# [11849/11880 | 99.74%] 010191.jpg vs 032973.jpg | ArcFace | opencv | Metric: cosine | ETA: 1m 0s
#   [x] GAGAL: Exception while processing img1_path
# [11850/11880 | 99.75%] 010191.jpg vs 032973.jpg | ArcFace | opencv | Metric: euclidean | ETA: 0m 58s
#   [x] GAGAL: Exception while processing img1_path
# [11851/11880 | 99.76%] 010191.jpg vs 032973.jpg | ArcFace | ssd | Metric: cosine | ETA: 0m 56s
# [11852/11880 | 99.76%] 010191.jpg vs 032973.jpg | ArcFace | ssd | Metric: euclidean | ETA: 0m 54s
# [11853/11880 | 99.77%] 010191.jpg vs 032973.jpg | ArcFace | mtcnn | Metric: cosine | ETA: 0m 52s
# [11854/11880 | 99.78%] 010191.jpg vs 032973.jpg | ArcFace | mtcnn | Metric: euclidean | ETA: 0m 50s
# [11855/11880 | 99.79%] 010191.jpg vs 032973.jpg | ArcFace | retinaface | Metric: cosine | ETA: 0m 48s
# [11856/11880 | 99.80%] 010191.jpg vs 032973.jpg | ArcFace | retinaface | Metric: euclidean | ETA: 0m 46s
# [11857/11880 | 99.81%] 024291.jpg vs 046844.jpg | Facenet | opencv | Metric: cosine | ETA: 0m 44s
# [11858/11880 | 99.81%] 024291.jpg vs 046844.jpg | Facenet | opencv | Metric: euclidean | ETA: 0m 42s
# [11859/11880 | 99.82%] 024291.jpg vs 046844.jpg | Facenet | ssd | Metric: cosine | ETA: 0m 40s
# [11860/11880 | 99.83%] 024291.jpg vs 046844.jpg | Facenet | ssd | Metric: euclidean | ETA: 0m 38s
# [11861/11880 | 99.84%] 024291.jpg vs 046844.jpg | Facenet | mtcnn | Metric: cosine | ETA: 0m 36s
# [11862/11880 | 99.85%] 024291.jpg vs 046844.jpg | Facenet | mtcnn | Metric: euclidean | ETA: 0m 34s
# [11863/11880 | 99.86%] 024291.jpg vs 046844.jpg | Facenet | retinaface | Metric: cosine | ETA: 0m 32s
# [11864/11880 | 99.87%] 024291.jpg vs 046844.jpg | Facenet | retinaface | Metric: euclidean | ETA: 0m 31s
# [11865/11880 | 99.87%] 024291.jpg vs 046844.jpg | OpenFace | opencv | Metric: cosine | ETA: 0m 29s
# [11866/11880 | 99.88%] 024291.jpg vs 046844.jpg | OpenFace | opencv | Metric: euclidean | ETA: 0m 27s
# [11867/11880 | 99.89%] 024291.jpg vs 046844.jpg | OpenFace | ssd | Metric: cosine | ETA: 0m 25s
# [11868/11880 | 99.90%] 024291.jpg vs 046844.jpg | OpenFace | ssd | Metric: euclidean | ETA: 0m 23s
# [11869/11880 | 99.91%] 024291.jpg vs 046844.jpg | OpenFace | mtcnn | Metric: cosine | ETA: 0m 21s
# [11870/11880 | 99.92%] 024291.jpg vs 046844.jpg | OpenFace | mtcnn | Metric: euclidean | ETA: 0m 19s
# [11871/11880 | 99.92%] 024291.jpg vs 046844.jpg | OpenFace | retinaface | Metric: cosine | ETA: 0m 17s
# [11872/11880 | 99.93%] 024291.jpg vs 046844.jpg | OpenFace | retinaface | Metric: euclidean | ETA: 0m 15s
# [11873/11880 | 99.94%] 024291.jpg vs 046844.jpg | ArcFace | opencv | Metric: cosine | ETA: 0m 13s
# [11874/11880 | 99.95%] 024291.jpg vs 046844.jpg | ArcFace | opencv | Metric: euclidean | ETA: 0m 11s
# [11875/11880 | 99.96%] 024291.jpg vs 046844.jpg | ArcFace | ssd | Metric: cosine | ETA: 0m 9s
# [11876/11880 | 99.97%] 024291.jpg vs 046844.jpg | ArcFace | ssd | Metric: euclidean | ETA: 0m 7s
# [11877/11880 | 99.97%] 024291.jpg vs 046844.jpg | ArcFace | mtcnn | Metric: cosine | ETA: 0m 5s
# [11878/11880 | 99.98%] 024291.jpg vs 046844.jpg | ArcFace | mtcnn | Metric: euclidean | ETA: 0m 3s
# [11879/11880 | 99.99%] 024291.jpg vs 046844.jpg | ArcFace | retinaface | Metric: cosine | ETA: 0m 1s
# [11880/11880 | 100.00%] 024291.jpg vs 046844.jpg | ArcFace | retinaface | Metric: euclidean | ETA: 0m 0s
#
# ✅ Proses Selesai. Hasil disimpan ke: 100photo_comparison_results.csv

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# --- Nama file input dan output ---
INPUT_CSV = "100photo_comparison_results.csv"
SUMMARY_CSV = "performance_summary.csv"

# --- LANGKAH 1: MEMBACA DAN MEMBERSIHKAN DATA ---
try:
    df = pd.read_csv(INPUT_CSV)
    print(f"Berhasil membaca {len(df)} baris dari {INPUT_CSV}")
except FileNotFoundError:
    print(f"ERROR: File '{INPUT_CSV}' tidak ditemukan. Pastikan skrip Tahap 1 sudah selesai dijalankan.")
    exit()

# Membersihkan data dari baris yang error saat eksekusi
df.dropna(inplace=True)
df = df[df['result_type'] != 'ERROR'].copy() # Menggunakan .copy() untuk menghindari SettingWithCopyWarning

# Konversi kolom boolean jika perlu
df['verified'] = df['verified'].astype(bool)
df['is_same_person'] = df['is_same_person'].astype(bool)

print(f"Jumlah data setelah dibersihkan: {len(df)} baris.")

# --- LANGKAH 2: MENGHITUNG METRIK UNTUK SETIAP KONFIGURASI ---

# Kelompokkan data berdasarkan model, backend, dan metrik
grouped = df.groupby(['model', 'backend', 'similarity_metric'])

summary_data = []

# Loop untuk setiap grup konfigurasi
for name, group in grouped:
    model_name, backend_name, metric_name = name
    
    # y_true adalah label asli (apakah orangnya benar-benar sama)
    # y_pred adalah prediksi model (apakah diverifikasi sebagai sama)
    y_true = group['is_same_person']
    y_pred = group['verified']
    
    # Jika tidak ada sampel positif, metrik recall/precision/f1 tidak terdefinisi
    if y_true.sum() == 0:
        print(f"Peringatan: Tidak ada sampel positif untuk grup {name}. Metrik tidak bisa dihitung.")
        continue

    # Hitung metrik utama
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, zero_division=0)
    recall = recall_score(y_true, y_pred, zero_division=0)
    f1 = f1_score(y_true, y_pred, zero_division=0)
    
    # Hitung TP, TN, FP, FN secara manual dari confusion matrix untuk validasi
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred, labels=[False, True]).ravel()

    summary_data.append({
        "Model": model_name,
        "Backend": backend_name,
        "Metric": metric_name,
        "Accuracy": round(accuracy, 4),
        "Precision": round(precision, 4),
        "Recall (Sensitivity)": round(recall, 4), # Recall juga disebut Sensitivity atau True Positive Rate
        "F1-Score": round(f1, 4),
        "TP": tp,
        "TN": tn,
        "FP": fp,
        "FN": fn
    })

# --- LANGKAH 3: TAMPILKAN DAN SIMPAN HASIL AKHIR ---
if summary_data:
    df_summary = pd.DataFrame(summary_data)
    
    # Urutkan berdasarkan F1-Score (metrik terbaik untuk keseimbangan precision-recall)
    df_summary_sorted = df_summary.sort_values(by="F1-Score", ascending=False)
    
    print("\n" + "="*80)
    print("           RINGKASAN PERFORMA PIPELINE VERIFIKASI WAJAH")
    print("="*80)
    # Gunakan to_string() agar semua kolom ditampilkan
    print(df_summary_sorted.to_string())
    
    # Simpan tabel ringkasan ke file CSV
    df_summary_sorted.to_csv(SUMMARY_CSV, index=False)
    print(f"\n✅ Ringkasan performa disimpan ke '{SUMMARY_CSV}'")
else:
    print("\nTidak ada data valid untuk dianalisis.")
# Out:
# Berhasil membaca 11364 baris dari 100photo_comparison_results.csv
# Jumlah data setelah dibersihkan: 5682 baris.
#
# ================================================================================
#            RINGKASAN PERFORMA PIPELINE VERIFIKASI WAJAH
# ================================================================================
#        Model     Backend  Metric  Accuracy  Precision  Recall (Sensitivity)  F1-Score   TP  TN  FP   FN
# 1    ArcFace      opencv  cosine    0.8924     1.0000                0.8845    0.9387  337  28   0   44
# 0    ArcFace       mtcnn  cosine    0.8465     0.9973                0.8333    0.9080  375  44   1   75
# 2    ArcFace  retinaface  cosine    0.8303     0.9973                0.8156    0.8973  367  44   1   83
# 3    ArcFace         ssd  cosine    0.8081     0.9972                0.7911    0.8823  356  44   1   94
# 5    Facenet      opencv  cosine    0.6161     1.0000                0.5879    0.7405  224  28   0  157
# 6    Facenet  retinaface  cosine    0.6202     1.0000                0.5822    0.7360  262  45   0  188
# 7    Facenet         ssd  cosine    0.5980     1.0000                0.5578    0.7161  251  45   0  199
# 4    Facenet       mtcnn  cosine    0.5778     1.0000                0.5356    0.6975  241  45   0  209
# 9   OpenFace      opencv  cosine    0.1198     1.0000                0.0551    0.1045   21  28   0  360
# 10  OpenFace  retinaface  cosine    0.1253     1.0000                0.0378    0.0728   17  45   0  433
# 8   OpenFace       mtcnn  cosine    0.1232     1.0000                0.0356    0.0687   16  45   0  434
# 11  OpenFace         ssd  cosine    0.1172     0.9333                0.0311    0.0602   14  44   1  436
#
# ✅ Ringkasan performa disimpan ke 'performance_summary.csv'
